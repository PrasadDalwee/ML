# %%
import pandas as pd
# df=pd.read_csv("amazon.csv")
# df.tail()

# %%
# df1=df
# for i in range(len(df.index)):
#     df['product_name'].iloc[i]=df.iloc[i]['product_name']+str(i)
#     #print(df.iloc[i]['product_name']+str(i))
# df.to_csv("amazon2.csv", index=False)
# df1['product_name'].iloc[0]

# %%
df=pd.read_csv('amazon2.csv')
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                             Hornby 2014 Catalogue0       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3    HORNBY Coach R4410A BR Hawksworth Corridor 3rd3       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# 2                     2 new                17                           2.0
# 3                       NaN                 1                           2.0
# 4                       NaN                 3                           2.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 1    4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 2    3.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 3    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 4    4.7 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                                NaN
# 4                                                NaN
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                                NaN
# 4                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   uniq_id                                      10000 non-null  object
#  1   product_name                                 10000 non-null  object
#  2   manufacturer                                 9993 non-null   object
#  3   price                                        8565 non-null   object
#  4   number_available_in_stock                    7500 non-null   object
#  5   number_of_reviews                            9982 non-null   object
#  6   number_of_answered_questions                 9235 non-null   float64
#  7   average_review_rating                        9982 non-null   object
#  8   amazon_category_and_sub_category             9310 non-null   object
#  9   customers_who_bought_this_item_also_bought   8938 non-null   object
#  10  description                                  9349 non-null   object
#  11  product_information                          9942 non-null   object
#  12  product_description                          9349 non-null   object
#  13  items_customers_buy_after_viewing_this_item  6935 non-null   object
#  14  customer_questions_and_answers               914 non-null    object
#  15  customer_reviews                             9979 non-null   object
#  16  sellers                                      6918 non-null   object
# dtypes: float64(1), object(16)
# memory usage: 1.3+ MB

# %%
df.isna().sum()
# Out:
# uniq_id                                           0
# product_name                                      0
# manufacturer                                      7
# price                                          1435
# number_available_in_stock                      2500
# number_of_reviews                                18
# number_of_answered_questions                    765
# average_review_rating                            18
# amazon_category_and_sub_category                690
# customers_who_bought_this_item_also_bought     1062
# description                                     651
# product_information                              58
# product_description                             651
# items_customers_buy_after_viewing_this_item    3065
# customer_questions_and_answers                 9086
# customer_reviews                                 21
# sellers                                        3082
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# # Predicting missing Categories of products with the help of description and name

# %%
df.amazon_category_and_sub_category[1]
# Out:
# 'Hobbies > Model Trains & Railway Sets > Rail Vehicles > Trains'

# %%
df.amazon_category_and_sub_category[1].index(' >')
# Out:
# 7

# %%
df.amazon_category_and_sub_category[1]
# Out:
# 'Hobbies > Model Trains & Railway Sets > Rail Vehicles > Trains'

# %% [markdown]
# ## Category Series

# %%
category = pd.Series(df['amazon_category_and_sub_category'].fillna('Buffer'))
category
# Out:
# 0       Hobbies > Model Trains & Railway Sets > Rail V...
# 1       Hobbies > Model Trains & Railway Sets > Rail V...
# 2       Hobbies > Model Trains & Railway Sets > Rail V...
# 3       Hobbies > Model Trains & Railway Sets > Rail V...
# 4       Hobbies > Model Trains & Railway Sets > Rail V...
#                               ...
# 9995    Hobbies > Collectible Figures & Memorabilia > ...
# 9996               Characters & Brands > Star Wars > Toys
# 9997    Novelty & Special Use > Novelty > Accessories ...
# 9998    Hobbies > Collectible Figures & Memorabilia > ...
# 9999               Characters & Brands > Star Wars > Toys
# Name: amazon_category_and_sub_category, Length: 10000, dtype: object

# %%
category.unique()
# Out:
# array(['Hobbies > Model Trains & Railway Sets > Rail Vehicles > Trains',
#        'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Lamps & Lighting',
#        'Hobbies > Model Trains & Railway Sets > Rail Vehicles > Locomotives',
#        'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Signal & Sound',
#        'Hobbies > Model Trains & Railway Sets > Accessories > Recreational Activities',
#        'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Transformers & Decoders',
#        'Buffer',
#        'Characters & Brands > Thomas & Friends > Train Play > Wooden Thomas',
#        'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Control Moduls',
#        'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping',
#        'Characters & Brands > Thomas & Friends > Train Play > Motor Road & Rail',
#        'Characters & Brands > Hasbro',
#        'Characters & Brands > Star Wars > Toys',
#        'Characters & Brands > Disney > Toys', 'Fancy Dress > Costumes',
#        'Bags > Schoolbags & Backpacks > Bags',
#        "Arts & Crafts > Children's Craft Kits",
#        'Characters & Brands > Tomy', "Handbags & Shoulder Bags > Kids'",
#        'Games > Dice & Dice Games', 'Games > Board Games',
#        'Arts & Crafts > Art Sand', 'Arts & Crafts > Felt Kits',
#        'Figures & Playsets > Farm & Animals',
#        'Characters & Brands > Barbie',
#        'Home Accessories > Decorative Accessories > Stickers > Window Stickers',
#        'Arts & Crafts > Art & Craft Supplies > Glitter',
#        'Figures & Playsets > Pirates',
#        'Figures & Playsets > Science Fiction & Fantasy',
#        'Figures & Playsets > Knights & Castles',
#        'Sweets, Chocolate & Gum > Chocolate',
#        'Sports Toys & Outdoor > Beach Toys > Beach Toys',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Vehicles',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Boats',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Trains',
#        'Baby & Toddler Toys > Pushchair Toys',
#        'Hobbies > Model Building Kits > Figures',
#        'Characters & Brands > Action Man',
#        'Characters & Brands > Toy Story > Toys',
#        'Hobbies > Collectible Figures & Memorabilia > Collectible Figures & Accessories',
#        'Hobbies > Collectible Figures & Memorabilia > Collectible Props & Memorabilia',
#        'Hobbies > Collectible Figures & Memorabilia > Bobbleheads & Busts',
#        'Characters & Brands > Harry Potter > Toys',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Rockets & Spaceships',
#        'Fancy Dress > Accessories',
#        "Arts & Crafts > Children's Craft Kits > Bead Art & Jewellery-Making",
#        "Arts & Crafts > Children's Chalk", 'Arts & Crafts > Blackboards',
#        'Storage, Cleaning & Ring Sizers > Boxes & Organisers',
#        "Bedding & Linens > Children's Bedding > Sheets & Pillowcases > Flat Sheets",
#        'Characters & Brands > Crayola',
#        'Arts & Crafts > Paper & Stickers',
#        'Arts & Crafts > Painting By Numbers',
#        'Characters & Brands > Early Learning Centre',
#        'Office Supplies > Labels, Index Dividers & Stamps > Labels & Stickers',
#        'Hobbies > Model Building Kits > Model Building Tools',
#        'Home Accessories > Seasonal Décor > Christmas',
#        'Party Supplies > Banners, Stickers & Confetti > Banners',
#        'Arts & Crafts > Doll Making',
#        'Sports Toys & Outdoor > Beach Toys > Airbeds & Inflating Devices',
#        'Sports Toys & Outdoor > Beach Toys > Water Pistols',
#        'Sports Toys & Outdoor > Beach Toys > Paddling Pools',
#        'Sports Toys & Outdoor > Beach Toys > Water Play Tables',
#        'Sports Toys & Outdoor > Beach Toys > Flotation Devices & Accessories',
#        'Camping & Hiking > Sleeping Gear > Air Pumps > Hand Pumps',
#        'Pretend Play > Play Tools',
#        'Fancy Dress > Accessories > Sets & Kits',
#        'Fancy Dress > Costumes > Adults',
#        'Fancy Dress > Costumes > Kids & Toddlers',
#        'Fancy Dress > Accessories > Temporary Tattoos',
#        'Women > Accessories',
#        'Hobbies > Slot Cars, Race Tracks & Accessories > Race Tracks',
#        'Hobbies > Remote Controlled Devices > Robots',
#        'Hobbies > Remote Controlled Devices > Tanks',
#        'Hobbies > Slot Cars, Race Tracks & Accessories',
#        'Electronic Toys > Robots',
#        'Hobbies > Slot Cars, Race Tracks & Accessories > Slot Cars',
#        'Hobbies > Slot Cars, Race Tracks & Accessories > Service & Tuning Parts',
#        'Hobbies > Remote Controlled Devices > Helicopters & Quadcopters',
#        'Hobbies > Remote Controlled Devices > Parts & Accessories',
#        'Electronic Toys > Kids Remote & App Controlled Toys',
#        'Hobbies > Model Building Kits > Accessories',
#        'Car Parts > Instruments > Nuts & Bolts',
#        'Hobbies > Trading Cards & Accessories > Packs & Sets',
#        'Hobbies > Model Building Kits',
#        'Hobbies > Model Building Kits > Boats & Watercraft',
#        'Baby & Toddler Toys > Spinning Tops',
#        'Party Supplies > Party Favours',
#        'Dolls & Accessories > Fashion Dolls & Accessories',
#        'Characters & Brands > Bob the Builder > Toys',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Friction Cars',
#        'Baby & Toddler Toys > Teaching Clocks',
#        'Indoor Lighting > Specialty & Decorative Lighting > Book Lights',
#        'Figures & Playsets > Cowboys & Indians',
#        'Figures & Playsets > Accessories',
#        'Games > Casino Equipment > Game Sets > Poker Sets',
#        'Characters & Brands > BRIO > BRIO Builder System',
#        'Figures & Playsets > Transportation & Traffic',
#        'Characters & Brands > Barbie > Barbie Dolls & Accessories',
#        'Educational Toys > Mathematics',
#        'Characters & Brands > BRIO > BRIO Wooden Railway System',
#        'Electronic Toys > Digital Cameras',
#        'Laundry, Storage & Organisation > Baskets & Bins > Storage Boxes & Chests > Storage Boxes',
#        "Supporters' Gear > Football > Memorabilia & Collectibles",
#        'Jams, Honey & Spreads > Sandwich Spreads, Pates & Pastes',
#        'Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Albums',
#        'Games > Casino Equipment > Game Sets',
#        'Novelty & Special Use > Novelty',
#        "Characters & Brands > Upstarts > Children's Games",
#        'Sweets, Chocolate & Gum > Chocolate > Bars > Multipack Bars',
#        'Party Supplies > Decorations > Balloons',
#        'Party Supplies > Decorations > Props',
#        'Musical Toy Instruments > Guitars & Strings',
#        'Party Supplies > Banners, Stickers & Confetti > Streamers',
#        'Party Supplies > Decorations > Cake Decorations',
#        'Party Supplies > Invitations', 'Party Supplies > Party Tableware',
#        'Men > Tops & T-Shirts > T-Shirts',
#        "Sex & Sensuality > Erotic Clothing > Women's > Costumes",
#        'Novelty & Special Use > Novelty > Accessories > Buttons & Pins',
#        'Fancy Dress > Accessories > Capes & Wings',
#        'Fancy Dress > Accessories > Hats',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Toy Cars & Trucks',
#        'Hobbies > Model Building Kits > Tanks',
#        'Hobbies > Model Building Kits > Steam Engines',
#        'Hobbies > Model Trains & Railway Sets > Accessories',
#        'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Landscape Architecture',
#        'Hobbies > Model Trains & Railway Sets > Accessories > Figures & Decoration Parts > Figures',
#        'Fancy Dress > Accessories > Masks',
#        'Women > Accessories > Eyewear & Accessories > Sunglasses',
#        'Figures & Playsets > Emergency Services',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models',
#        'Characters & Brands > Thunderbirds > Toys',
#        'Hobbies > Model Building Kits > Cars & Vehicles',
#        'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Coasters',
#        'Hobbies > Model Trains & Railway Sets',
#        'Medication & Remedies > Alternative Medicine',
#        'Sports Toys & Outdoor > Bikes, Trikes & Ride-ons',
#        'Puppets & Puppet Theatres > Finger Puppets',
#        'Indoor Lighting > Specialty & Decorative Lighting',
#        'Baby & Toddler Toys > Activity Centres',
#        'Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Scooters',
#        'Medication & Remedies > Pain & Fever > Hot & Cold Therapies',
#        'Puppets & Puppet Theatres > Hand Puppets',
#        'Jigsaws & Puzzles > 3-D Puzzles',
#        'Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Sleeves',
#        'Hobbies > Trading Cards & Accessories > Sticker Collections',
#        'Characters & Brands > Ravensburger',
#        'Jigsaws & Puzzles > Jigsaws',
#        'Hobbies > Trading Cards & Accessories > Storage Albums & Cases > Cases',
#        'Jigsaws & Puzzles > Brain Teasers',
#        'Jigsaws & Puzzles > Frame Jigsaws',
#        'Characters & Brands > Ravensburger > Games',
#        'Musical Toy Instruments > Pianos & Keyboards',
#        'Party Supplies > Banners, Stickers & Confetti > Garlands',
#        'Arts & Crafts > Art & Craft Supplies > Thread > Sewing',
#        'Party Supplies > Banners, Stickers & Confetti > Confetti',
#        'Games > Card Games',
#        'Hobbies > Trading Cards & Accessories > Single Cards',
#        'Games > Casino Equipment > Game Layouts > Poker Layouts',
#        'Hobbies > Trading Cards & Accessories',
#        "Characters & Brands > Marvin's Magic", 'Games > Chess',
#        'Games > Casino Equipment > Game Tables > Poker Tables',
#        'Games > Casino Equipment > Bingo Equipment',
#        'Games > Casino Equipment > Game Layouts > Craps Layouts',
#        'Games > Casino Equipment > Game Sets > Blackjack Sets',
#        'Games > Casino Equipment > Poker Chips',
#        'Games > Casino Equipment > Poker Chip Cases & Trays > Cases',
#        'Games > Casino Equipment > Game Sets > Roulette Sets',
#        'Characters & Brands > Harry Potter > Books > Stationery',
#        'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Track Construction',
#        'Hobbies > Model Trains & Railway Sets > Accessories > Landscaping > Road Construction',
#        'Hobbies > Model Trains & Railway Sets > Lighting & Signal Engineering > Cable',
#        'Dogs > Clothing & Accessories > Costumes',
#        'Figures & Playsets > Dinosaurs',
#        'Characters & Brands > Winnie-the-Pooh > Toys',
#        'Characters & Brands > VTech',
#        'Medical Supplies & Equipment > Braces, Splints & Slings > Tape & Supplies',
#        'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Ice Cube Moulds & Trays',
#        'Musical Toy Instruments > Wind & Brass',
#        'Characters & Brands > Action Man > Toys',
#        'Home Accessories > Seasonal Décor > Christmas > Novelty Decorations',
#        'Office Supplies > Desk Accessories & Storage Products > Desk Supplies Organisers & Dispensers > Desk Supplies Organisers',
#        'Arts & Crafts > Colouring Pens & Markers',
#        'Arts & Crafts > Colouring Pencils',
#        'Arts & Crafts > Drawing & Painting Supplies > Paints > Poster Paints',
#        'Pens, Pencils & Writing Supplies > Markers & Highlighters > Permanent Markers & Marker Pens',
#        'Pens, Pencils & Writing Supplies > Erasers & Correction Supplies > Erasers',
#        'Pens, Pencils & Writing Supplies > Pencils > Coloured Pencils',
#        'Pens, Pencils & Writing Supplies > Erasers & Correction Supplies > Correction Pens',
#        'Pens, Pencils & Writing Supplies > Pens & Refills > Pen Refills',
#        'Pens, Pencils & Writing Supplies > Markers & Highlighters > Art Markers',
#        'Baby & Toddler Toys > Sorting, Stacking & Plugging Toys',
#        'Baby & Toddler Toys > Sound Toys',
#        'Baby & Toddler Toys > Rocking Horses',
#        'Baby & Toddler Toys > Rattles',
#        'Baby & Toddler Toys > Learning & Activity Toys',
#        'Baby & Toddler Toys > Rockers & Ride-ons',
#        "Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' House Accessories",
#        'Die-Cast & Toy Vehicles > Toy Trains & Accessories > Toy Trains & Sets',
#        'Educational Toys > Literacy & Spelling',
#        'Games > Tabletop & Miniature Gaming', 'Characters & Brands > WWE',
#        'Figures & Playsets > Sport',
#        'Sports Toys & Outdoor > Kites & Flight Toys',
#        'Worlds Apart > Kid Venture > Kites',
#        'Sports Toys & Outdoor > Garden Tools',
#        'Sports Toys & Outdoor > Darts & Accessories',
#        'Sports Toys & Outdoor > Climbing Frames',
#        'Gardening > Hand Tools > Gardening Trowels',
#        'Sports Toys & Outdoor > Cup & Ball Games',
#        'Gardening > Greenhouses & Plant Germination Equipment > Greenhouses',
#        'Sports Toys & Outdoor > Target Games',
#        'Sports Toys & Outdoor > Racket Games',
#        "Characters & Brands > Ravensburger > Children's Puzzles",
#        'Jigsaws & Puzzles > Jigsaw Accessories',
#        'Die-Cast & Toy Vehicles > Toy Vehicles & Accessories > Scaled Models > Aircraft',
#        'Characters & Brands > BRIO > BRIO Wooden Roadway System',
#        'Hobbies > Model Trains & Railway Sets > Rail Vehicles > Wagons',
#        'Characters & Brands > Thomas & Friends > Ages 3-4 Years',
#        'Characters & Brands > Thomas & Friends > Train Play > Take Along Thomas',
#        'Hobbies > Model Trains & Railway Sets > Starter Packs & Sets',
#        'Lab & Scientific Products > Lab Instruments & Equipment > Microscopes & Equipment > Microscopes',
#        'Die-Cast & Toy Vehicles > Toy Vehicle Playsets',
#        'Party Supplies > Party Bags', 'Dolls & Accessories > Playsets',
#        'Dolls & Accessories > Fashion Dolls & Accessories > Vehicles',
#        'Dolls & Accessories > Fashion Dolls & Accessories > Houses',
#        'Dolls & Accessories > Soft Dolls',
#        "Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Children's Bikes",
#        'Games > Educational Games', 'Pretend Play > Shops & Accessories',
#        'Puppets & Puppet Theatres > Accessories',
#        "Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' House Furniture",
#        "Dolls & Accessories > Dolls' House Dolls & Accessories > Dolls' Houses",
#        'Figures & Playsets > Military', 'Games > Strategy Games',
#        'Characters & Brands > LeapFrog > LeapPad Learning System',
#        'Characters & Brands > Hornby', 'Characters & Brands > LeapFrog',
#        'Games > Dominoes & Tile Games',
#        'Sports Toys & Outdoor > Bikes, Trikes & Ride-ons > Push Power Ride-ons & Accessories > Push Power Ride-ons',
#        'Games > Mystery Games',
#        'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Straws',
#        'Games > DVD Games', 'Games > Trivia & Quiz Games',
#        'Electronic Toys > Educational Computers & Accessories',
#        'Women > Tops & T-Shirts',
#        'Characters & Brands > Upstarts > Family Games',
#        'Dolls & Accessories > Fashion Dolls & Accessories > Fashion Dolls',
#        'Cooking & Dining > Kitchen Tools & Gadgets > Barware > Glass Markers & Charms',
#        "Arts & Crafts > Children's Craft Kits > Children's Knitting & Textile Design",
#        'Novelty Jewellery > Charms > Bead Charms',
#        'Games > Travel & Pocket Games', 'Games > Drinking Games'],
#       dtype=object)

# %%
category.nunique()
# Out:
# 256

# %%
def main_category(x):
    n=x.find(' >')
    if(n>0):
        return x[:n]
    return x

category=category.apply( lambda x: main_category(x))

# %%
import matplotlib.pyplot as plt
def count_plot(arr):
    freq = {}
    plt.figure(figsize=(30,10))
    
    for item in category:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
 
    for i in sorted(freq):
        print(i,freq[i])
        if(freq[i]>100):
            plt.bar(i, freq[i], color='g',width=0.5)


n=category.unique()
print('Total categories: ',len(n),' \n\n')
count_plot(n)
# Out:
# Total categories:  44
#
#
# Arts & Crafts 802
# Baby & Toddler Toys 106
# Bags 4
# Bedding & Linens 1
# Buffer 690
# Camping & Hiking 1
# Car Parts 1
# Characters & Brands 960
# Cooking & Dining 4
# Die-Cast & Toy Vehicles 1221
# Dogs 2
# Dolls & Accessories 371
# Educational Toys 3
# Electronic Toys 5
# Fancy Dress 585
# Figures & Playsets 1111
# Games 941
# Gardening 3
# Handbags & Shoulder Bags 1
# Hobbies 1464
# Home Accessories 5
# Indoor Lighting 2
# Jams, Honey & Spreads 1
# Jigsaws & Puzzles 274
# Lab & Scientific Products 1
# Laundry, Storage & Organisation 1
# Medical Supplies & Equipment 1
# Medication & Remedies 2
# Men 1
# Musical Toy Instruments 19
# Novelty & Special Use 11
# Novelty Jewellery 1
# Office Supplies 6
# Party Supplies 694
# Pens, Pencils & Writing Supplies 7
# Pretend Play 45
# Puppets & Puppet Theatres 269
# Sex & Sensuality 1
# Sports Toys & Outdoor 372
# Storage, Cleaning & Ring Sizers 1
# Supporters' Gear 2
# Sweets, Chocolate & Gum 2
# Women 3
# Worlds Apart 3

# %%
category.index[71]
# Out:
# 71

# %% [markdown]
# ## Missing Category DF

# %%
c=df[['product_name','amazon_category_and_sub_category', 'description']]
c=c[df['amazon_category_and_sub_category'].isnull()]
c=c.dropna(subset=['description'])
c
# Out:
#                                            product_name  \
# 71                      Power Trains Auto Loader City71
# 199                            Smasha Ballz Ninjaaah199
# 200   Moomins - 6.5 Inch Moominpappa Soft Toy - 2005...
# 201   Classic Cuddly Paddington Bear by Rainbow Desi...
# 202   Charlie Bears Rainbow Teddy Bear from the Char...
# ...                                                 ...
# 9113  Mega Bloks Halo 97134 - UNSC Night Ops Gaussho...
# 9333  Fajiabao Educational Classic Electronic Racing...
# 9434  Hungry Hungry Hippos Elefun & Friends Board Ga...
# 9664  Friendship Charm Bracelet Jewellery Making Kit...
# 9961  Stark Sigil Pendant (costume) Game of Thrones ...
#
#      amazon_category_and_sub_category  \
# 71                                NaN
# 199                               NaN
# 200                               NaN
# 201                               NaN
# 202                               NaN
# ...                               ...
# 9113                              NaN
# 9333                              NaN
# 9434                              NaN
# 9664                              NaN
# 9961                              NaN
#
#                                             description
# 71                   Power City Trains Auto Loader City
# 199   Product Description The Smasha-Ballz have inva...
# 200                                   6.5 inch soft toy
# 201   Please take care of this bear... Cuddly Paddin...
# 202                 Rainbow is from the 2015 collection
# ...                                                 ...
# 9113  Product Description Establish your army, build...
# 9333  Colour Name:style A High emulation car，props (...
# 9434  Style Name:Friends-Board Game Hungry Hungry Hi...
# 9664  PIPPIN FRIENDSHIP CHARM BRACELET KIT - HEARTS ...
# 9961  A metal 3.5cm pendant in the form of the House...
#
# [657 rows x 3 columns]

# %%
missing=c

# %% [markdown]
# ## Category DF

# %%
category_df=df[['product_name','description','amazon_category_and_sub_category']].fillna('Buffer')
category_df.isnull().sum()
# Out:
# product_name                        0
# description                         0
# amazon_category_and_sub_category    0
# dtype: int64

# %%
def main_category(x):
    n=x.find(' >')
    if(n>0):
        return x[:n]
    return x

category=category.apply( lambda x: main_category(x))
category_df['amazon_category_and_sub_category']=category

# %%
category_df.head()
# Out:
#                                         product_name  \
# 0                             Hornby 2014 Catalogue0
# 1  FunkyBuys® Large Christmas Holiday Express Fes...
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3    HORNBY Coach R4410A BR Hawksworth Corridor 3rd3
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#   amazon_category_and_sub_category
# 0                          Hobbies
# 1                          Hobbies
# 2                          Hobbies
# 3                          Hobbies
# 4                          Hobbies

# %% [markdown]
# ## Classification

# %%
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                             Hornby 2014 Catalogue0       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3    HORNBY Coach R4410A BR Hawksworth Corridor 3rd3       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# 2                     2 new                17                           2.0
# 3                       NaN                 1                           2.0
# 4                       NaN                 3                           2.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 1    4.5 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 2    3.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 3    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# 4    4.7 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
#
#                                          description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#                                  product_information  \
# 0  Technical Details Item Weight640 g Product Dim...
# 1  Technical Details Manufacturer recommended age...
# 2  Technical Details Manufacturer recommended age...
# 3  Technical Details Item Weight259 g Product Dim...
# 4  Technical Details Item Weight159 g Product Dim...
#
#                                  product_description  \
# 0  Product Description Hornby 2014 Catalogue Box ...
# 1  Size Name:Large FunkyBuys® Large Christmas Hol...
# 2  BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3  Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4  Product Description Hornby RailRoad 0-4-0 Gild...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
#
#                       customer_questions_and_answers  \
# 0  Does this catalogue detail all the previous Ho...
# 1  can you turn off sounds // hi no you cant turn...
# 2  What is the gauge of the track // Hi Paul.Trut...
# 3                                                NaN
# 4                                                NaN
#
#                                     customer_reviews  \
# 0  Worth Buying For The Pictures Alone (As Ever) ...
# 1  Four Stars // 4.0 // 18 Dec. 2015 // By\n    \...
# 2  **Highly Recommended!** // 5.0 // 26 May 2015 ...
# 3  I love it // 5.0 // 22 July 2013 // By\n    \n...
# 4  Birthday present // 5.0 // 14 April 2014 // By...
#
#                                              sellers
# 0  {"seller"=>[{"Seller_name_1"=>"Amazon.co.uk", ...
# 1  {"seller"=>{"Seller_name_1"=>"UHD WHOLESALE", ...
# 2  {"seller"=>[{"Seller_name_1"=>"DEAL-BOX", "Sel...
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ## Vectorization

# %%
tfidf = TfidfVectorizer(stop_words='english')

overview_matrix = tfidf.fit_transform(category_df['description'])
overview_matrix2 = tfidf.fit_transform(category_df['product_name'])

similarity_matrix = linear_kernel(overview_matrix,overview_matrix)
similarity_matrix2 = linear_kernel(overview_matrix2,overview_matrix2)

print('\n\n similarity_matrix2: \n',similarity_matrix)

mapping = pd.Series(category_df.index,index = category_df['product_name'])
mapping
# Out:
#  similarity_matrix2:
#  [[1.         0.         0.         ... 0.         0.         0.        ]
#  [0.         1.         0.15582528 ... 0.         0.         0.        ]
#  [0.         0.15582528 1.         ... 0.         0.00685409 0.        ]
#  ...
#  [0.         0.         0.         ... 1.         0.01698311 0.        ]
#  [0.         0.         0.00685409 ... 0.01698311 1.         0.        ]
#  [0.         0.         0.         ... 0.         0.         1.        ]]
# product_name
# Hornby 2014 Catalogue0                                                                                                        0
# FunkyBuys® Large Christmas Holiday Express Festive Train Set (SI-TY1017) Toy Light / Sounds / Battery Operated & Smoke1       1
# CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT ENGINE BOXED BOYS KIDS BATTERY2                                                   2
# HORNBY Coach R4410A BR Hawksworth Corridor 3rd3                                                                               3
# Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam Locomotive Model4                                                              4
#                                                                                                                            ...
# Batman 1966 TV Series Action Figures - The Riddler9995                                                                     9995
# Star Wars Costume, Kids Stormtrooper Costume Style 4, Medium, HEIGHT 4' 2" - 4' 6"9996                                     9996
# Defiance Lawkeeper Metal Badge Prop Replica9997                                                                            9997
# Justice League of America Series 3 Green Lantern Action Figure9998                                                         9998
# Star Wars 1/72 Y-Wing Starfighter9999                                                                                      9999
# Length: 10000, dtype: int64

# %%
def category_pred(df_input):
    
    def description(df_input):
        df_index = mapping[df_input]
        similarity_score = list(enumerate(similarity_matrix[df_index]))
        similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
        similarity_score = similarity_score[1:2]
#         print(similarity_score)
        df_indices = [i[0] for i in similarity_score]
        return (similarity_score)
    
    def name(df_input):
        df_index = mapping[df_input]
        similarity_score = list(enumerate(similarity_matrix2[df_index]))
        similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
        similarity_score = similarity_score[1:2]
#         print(similarity_score)
        df_indices = [i[0] for i in similarity_score]
        return (similarity_score)
    
    df_index = mapping[df_input]
    
    d=description(df_input)
    n=name(df_input)
    
    if d[0][1]<n[0][1]:
        index=n[0][0]
    else:
        index=d[0][0]
#     print(df_input,mapping[df_input],category_df['product_name'].iloc[df_index])

#     def fill_cat(index):
#        df['amazon_category_and_sub_category'].iloc[df_index]=df['amazon_category_and_sub_category'].iloc[index]
#        print(df_input,' ',category_df['amazon_category_and_sub_category'].iloc[index],'\n\n')

        
#     fill_cat(index)
    return(category_df['amazon_category_and_sub_category'].iloc[index])

# %%
print(category_pred('Smasha Ballz Ninjaaah199'))
# Out:
# [(334, 0.7292917871174842)]
# [(334, 0.524477782642056)]
# ['Smasha Ballz Ninjaaah199', 'Buffer']

# %%
category_df.iloc[6199]
# Out:
# product_name                        Hollywood/Movie Night Theme Party - Giant Bann...
# description                                                                    Buffer
# amazon_category_and_sub_category                                       Party Supplies
# Name: 6199, dtype: object

# %%
category_df.iloc[2206]
# Out:
# product_name                                         Parrot Bebop Drone 2 (White)2206
# description                         Colour Name:White and Black Product Descriptio...
# amazon_category_and_sub_category                                              Hobbies
# Name: 2206, dtype: object

# %%
mapping.index[2206]
# Out:
# 'Parrot Bebop Drone 2 (White)2206'

# %%
for i in missing['product_name']:
    category_pred(i)
# Out:
# [(4281, 0.43454639229678804)]
# [(5765, 0.694683115671579)]
# Power Trains Auto Loader City71   Hobbies
#
#
# [(334, 0.7292917871174842)]
# [(334, 0.524477782642056)]
# Smasha Ballz Ninjaaah199   Buffer
#
#
# [(4425, 0.480042110436164)]
# [(343, 0.1986916923002174)]
# Moomins - 6.5 Inch Moominpappa Soft Toy - 20056200   Characters & Brands
#
#
# [(4602, 0.24439927390811617)]
# [(9267, 0.2202323971846143)]
# Classic Cuddly Paddington Bear by Rainbow Designs (colours vary)201   Puppets & Puppet Theatres
#
#
# [(5856, 0.40418390100612506)]
# [(340, 0.730603229303472)]
# Charlie Bears Rainbow Teddy Bear from the Charlie Bears 2015 Plush Collection202   Buffer
#
#
# [(4413, 0.31130319649845933)]
# [(282, 0.37277130735909597)]
# Yoohoo & Friends - Bush Baby with Pink Love Heart Pink Eyes Plush Soft Toy203   Fancy Dress
#
#
# [(7958, 0.7351948211235363)]
# [(7958, 0.4982713514235344)]
# Monchhichi 45 cm Classic Boy204   Dolls & Accessories
#
#
# [(4509, 0.9703640090957549)]
# [(4509, 0.5828614969966651)]
# Aurora 5 inch Yoohoo and Friends Beaver205   Buffer
#
#
# [(8353, 0.9999999999999999)]
# [(8317, 0.5171777446057465)]
# The Puppet Company - Finger Puppets - Silverback Gorilla206   Puppets & Puppet Theatres
#
#
# [(9489, 0.2453004508873943)]
# [(300, 0.2435459650522181)]
# Burrows The Meerkat - TY Beanies 11" Classic207   Hobbies
#
#
# [(7816, 0.2743313810957743)]
# [(7816, 0.17428009179484988)]
# Henry Hugglemonster Summer 15 cm Soft Toy208   Die-Cast & Toy Vehicles
#
#
# [(6174, 0.18574074656348105)]
# [(4648, 0.35171711662732363)]
# Melissa & Doug Sack of Snakes209   Puppets & Puppet Theatres
#
#
# [(286, 0.22956168377124994)]
# [(3072, 0.19178027725683375)]
# Animal Babies Crunchy Munchy Baby Panda210   Buffer
#
#
# [(7142, 0.2816707734782957)]
# [(7142, 0.5498668234476475)]
# Olympic Mascots Union Jack Winning Wenlock211   Figures & Playsets
#
#
# [(4492, 0.8056168264992561)]
# [(4492, 0.614655173776973)]
# Aurora 7-inch Gruffalo Owl212   Sports Toys & Outdoor
#
#
# [(320, 0.3605627547348358)]
# [(320, 0.6758576760610568)]
# Suma Collection Plush Soft Toy Meerkat by Ravensden. 19cm. FRS016ME213   Buffer
#
#
# [(4405, 0.49778174965249883)]
# [(326, 0.32557300073379447)]
# Angry Birds Rio Soft Plush Toy Jewel Light Blue Bird 5 Inch214   Buffer
#
#
# [(4474, 0.7813440635697739)]
# [(298, 0.2522089115956436)]
# Thank You Teacher Me to You Bear Cards215   Buffer
#
#
# [(4413, 0.3752043919325744)]
# [(3133, 0.3124715391165024)]
# Creative Halloween Toy soft Plush Pumpkin - 35cm216   Buffer
#
#
# [(237, 0.10868885869702404)]
# [(237, 0.42997926562610045)]
# Squishable: Dragon218   Buffer
#
#
# [(4413, 0.19701728424786163)]
# [(4421, 0.23445263977364816)]
# Roadkill Toys - Smudge (Squirrel) Plush Toy219   Buffer
#
#
# [(4413, 0.15935431180716086)]
# [(5793, 0.28491109108985296)]
# Talking Friends Animated Talk Back Angela220   Hobbies
#
#
# [(4391, 0.3955212659275341)]
# [(350, 0.36976017909452585)]
# TY Kicks the Bear - Original Beanie Baby221   Buffer
#
#
# [(4492, 0.5885878860204832)]
# [(4564, 0.3289138974438092)]
# Gruffalo Fox 7 inch222   Sports Toys & Outdoor
#
#
# [(6434, 0.382428034623163)]
# [(1062, 0.21061432273833192)]
# Doom: Space Marine Plush223   Characters & Brands
#
#
# [(364, 0.28624589570506564)]
# [(364, 0.6257181863006163)]
# Latitude 320622 Simon the Lion224   Buffer
#
#
# [(250, 0.42954075171214695)]
# [(4431, 0.35640408804338425)]
# MBNF Join In and Play My Blue Nose Friend Binky The Panda225   Buffer
#
#
# [(8011, 0.21180111702115184)]
# [(1831, 0.39457163301240644)]
# Pink Fairy Princess Wand And Tiara Fits 15" Build A Bear226   Fancy Dress
#
#
# [(350, 0.5076821784594729)]
# [(261, 0.2999040346131341)]
# TY Juggles the Clown Beanie Baby227   Buffer
#
#
# [(239, 0.9492534620224522)]
# [(239, 0.4088797523934632)]
# Webkinz Orange Soda Pup Plush Toy229   Buffer
#
#
# [(1054, 0.37370545587797604)]
# [(4453, 0.24183960683973046)]
# Latest pokemon soft toy TSUTARJA new in uk ready to send230   Characters & Brands
#
#
# [(4692, 0.3339701821570182)]
# [(4372, 0.29635818546620657)]
# Wild Republic House Sparrow - Audubon Plush Bird (Authentic Bird Sound)231   Puppets & Puppet Theatres
#
#
# [(4431, 0.9999999999999998)]
# [(4422, 0.3847360411052677)]
# 9" I Love You Heart Me to You Bear232   Buffer
#
#
# [(6514, 0.6771092012823146)]
# [(4473, 0.3958607004377005)]
# Ty Beanie Baby Peppa Pig - Pirate George Plush Toy233   Figures & Playsets
#
#
# [(8053, 0.5114526409814376)]
# [(3910, 0.2319192369805188)]
# Itty Bitty Boo #18 Vampire Plush234   Dolls & Accessories
#
#
# [(302, 0.619836818087875)]
# [(302, 0.4782866348977026)]
# Steiff 28cm Ricky Teddy Bear (Light Brown)235   Buffer
#
#
# [(218, 0.10868885869702404)]
# [(218, 0.42997926562610045)]
# Mini Squishable Octopus237   Buffer
#
#
# [(4443, 0.28885762112672037)]
# [(4421, 0.3380433303785317)]
# Ice Age Beanie Babies - Sid238   Buffer
#
#
# [(229, 0.9492534620224522)]
# [(229, 0.4088797523934632)]
# Webkinz Delightz Chocolate Pup Plush Toy239   Buffer
#
#
# [(4367, 0.22207434599305464)]
# [(4367, 0.24962558621354408)]
# Plush Soft Toy Marble Lop Eared Rabbit. 30cm. (Assorted colours)240   Buffer
#
#
# [(350, 0.3698902089919237)]
# [(0, 0.0)]
# Bagpuss Beanie241   Buffer
#
#
# [(8249, 0.37073413505953745)]
# [(8249, 0.4193249197238669)]
# Ben & Holly 6" Soft Toy Holly243   Figures & Playsets
#
#
# [(1190, 0.310481745706587)]
# [(3159, 0.484882861092753)]
# Cute Paw Patrol Ryder Soft Toy New Paw Patrol Plush Toy Doll Xmas Gift244   Party Supplies
#
#
# [(2422, 0.3605547505602036)]
# [(4517, 0.5643336580922979)]
# Teddy Hermann Plush Soft Toy Penguin. 26cm.245   Buffer
#
#
# [(8290, 0.7379265615573865)]
# [(6057, 0.6611568422118702)]
# Kung Zhu Special Forces Hamster - Rocko246   Figures & Playsets
#
#
# [(4556, 0.8338913210188187)]
# [(358, 0.4678830078654904)]
# Me to You 5-inch Tatty Teddy Bear Holding a Congratulations Party Popper Plaque (Grey)247   Buffer
#
#
# [(229, 0.5655106915544206)]
# [(4547, 0.2901795900744417)]
# Webkinz Butterscotch Retreiver Soft Toy248   Buffer
#
#
# [(4497, 0.4604805351219503)]
# [(335, 0.17954313018105325)]
# Claire's Girls and Womens Small Beanie Flora The Skunk Soft Toy in Black/White249   Buffer
#
#
# [(4558, 0.8327301784251514)]
# [(4558, 0.47771144765306933)]
# Me To You 4-inch Tatty Teddy and My Blue Nose Friends Leboo The Masai Lion Soft Toy250   Buffer
#
#
# [(4430, 0.39315844532681704)]
# [(4800, 0.31521312363677556)]
# Webkinz Pug Plush Toy251   Buffer
#
#
# [(6072, 0.1729432055031621)]
# [(4383, 0.49527232906871177)]
# GIANTmicrobes Original White Lab Mouse Rat Educational Soft Toy Funny Science Gift253   Buffer
#
#
# [(4556, 0.8790216068753214)]
# [(357, 0.4629138923386231)]
# Me to You 7-inch Tall Tatty Teddy Limited Edition Teddy Bear Dressed as A Boxer (Grey)254   Buffer
#
#
# [(4430, 0.27417413845993066)]
# [(4543, 0.3110814551470661)]
# Ganz HS031 - Lil'Kinz Leopard Soft Toy 17 cm255   Buffer
#
#
# [(4390, 0.29574095234681097)]
# [(4390, 0.43891911116462323)]
# Aurora World 8-inch Mini Flopsie Horse (Hot Pink)256   Hobbies
#
#
# [(4442, 0.8584952101139272)]
# [(4442, 0.677841314176865)]
# Steiff 30cm Charly Dangling Teddy Bear (Brown)257   Buffer
#
#
# [(4477, 0.42506122627000353)]
# [(297, 0.4668804008628226)]
# Plush Soft Toy Sitting Grey Chinchilla by Hansa. 18cm. 5978258   Buffer
#
#
# [(350, 0.4997867071561165)]
# [(261, 0.2922709809381209)]
# Ewey the Lamb - Ty Beanie Baby259   Buffer
#
#
# [(302, 0.6301287839352785)]
# [(302, 0.47564875071980933)]
# Steiff 18cm Fynn Teddy Bear (Beige)260   Buffer
#
#
# [(350, 0.5818830852081273)]
# [(4429, 0.5497282858281156)]
# Ty Beanie Baby - Slowepoke261   Buffer
#
#
# [(266, 0.49775832968829953)]
# [(5582, 0.1886666040789483)]
# LALA - LAMM WEISS MIT GRUENEN262   Buffer
#
#
# [(4531, 0.14323232919251555)]
# [(4447, 0.31499048492684567)]
# Warmhearts Fully Microwavable Ragdoll Ellie263   Medication & Remedies
#
#
# [(348, 0.9999999999999999)]
# [(389, 0.32575074523362724)]
# Teddy Bear with chameleon, limb, slither, animal, reptile image t-shirt264   Buffer
#
#
# [(4413, 0.3237293214144291)]
# [(4367, 0.37459504519208064)]
# Keel Toys Cuddly Plush labrador on the lead Dog265   Buffer
#
#
# [(330, 0.9999999999999998)]
# [(4394, 0.18319464919158338)]
# TY 36148 - OSCAR - EULE MIT GL266   Buffer
#
#
# [(4413, 0.25378486411494977)]
# [(4375, 0.2653689507925693)]
# Doodle Jump 8-Inch Space Plush Toy267   Buffer
#
#
# [(4532, 0.33085538172695633)]
# [(6738, 0.2650046794792435)]
# Bluw 80's Stress Ball - Space Pixel269   Buffer
#
#
# [(4558, 0.7831706071513382)]
# [(4382, 0.5922370180367952)]
# Tatty Teddy & My Blue Nose Friends Noo the Wildebeest soft toy, sits 4" tall.270   Buffer
#
#
# [(294, 0.5201584334377112)]
# [(4490, 0.4152235577213097)]
# My Pillow Pets Fashion 1PC 40cm Despicable Me "It's So Fluffy" Agnus the Unicorn 16.5" Plush Pillow Doll271   Buffer
#
#
# [(4391, 0.3187991398855953)]
# [(1190, 0.23106240943792664)]
# Madagascar [tm] Melman the giraffe TY Beanie272   Buffer
#
#
# [(4413, 0.6160130727497137)]
# [(4528, 0.2828608695179635)]
# Pokemon Center Pokedoll 8.5 inch Shiny Gold Magikarp Plush Yellow Fish Toy273   Buffer
#
#
# [(111, 0.12608997235600078)]
# [(261, 0.46071209699975235)]
# Ty TY Beanie Baby - CLUBBY 6 the Bear (Rainbow Version)274   Buffer
#
#
# [(360, 0.496399764015616)]
# [(8209, 0.3662568395280824)]
# Luigi Kitsune 9" Plush Super Mario - Global Holding275   Buffer
#
#
# [(257, 0.4197616978733574)]
# [(257, 0.3458471146320593)]
# Steiff 35cm Hanno Dangling Hanoverian (Brown)276   Buffer
# [(4390, 0.34757772817837135)]
# [(320, 0.3204594637913276)]
# Flamingo Soft Toy - Suma Collection277   Hobbies
#
#
# [(4376, 0.8350256715844282)]
# [(4376, 0.5315202558259169)]
# WWF Wolf plush stuffed soft animal toy278   Buffer
#
#
# [(394, 0.7983715504351533)]
# [(345, 0.33721470216105687)]
# Melissa & Doug Jack Russell Terrier Plush Toy279   Buffer
#
#
# [(3453, 0.3416272062500436)]
# [(213, 0.28115630013736964)]
# Personalised meerkat plush toy with Happy holidays T-Shirt280   Die-Cast & Toy Vehicles
#
#
# [(367, 0.34676248884401)]
# [(315, 0.46749516147118425)]
# Keel Toys 110 cm Elephant281   Buffer
#
#
# [(4413, 0.39535609638436586)]
# [(6143, 0.2250085098138921)]
# 30cm Cuddlekins Triceratops from Wild Republic283   Buffer
#
#
# [(4386, 1.0000000000000002)]
# [(4404, 0.7083800998877919)]
# Official Nintendo Super Mario Plush Series Stuffed Toy - 10" Cat Luigi284   Buffer
#
#
# [(350, 0.5401119774944725)]
# [(350, 0.3115144354925883)]
# TY Chinook the Bear Canada Excl. Beanie Baby285   Buffer
#
#
# [(307, 0.29411728961351424)]
# [(1049, 0.31389672245166594)]
# Fisher-Price Giggle Gang - Kiwi286   Figures & Playsets
#
#
# [(370, 0.5473013226800452)]
# [(4518, 0.44549409740606866)]
# Purple Robe, PJ's, Boot Slippers & 2 Bows Teddy Bear Clothes fit Build a Bear factory Teddies287   Buffer
#
#
# [(6392, 0.29337300574354885)]
# [(6392, 0.2204741511585155)]
# ThinkGeek 40cm Alien Facehugger Plush Figure288   Figures & Playsets
#
#
# [(4411, 0.8048765266613463)]
# [(4411, 0.24155406434316884)]
# Sanei Tobidase Doubutsu No Mori Plush Toy Shizue289   Buffer
#
#
# [(6555, 0.5328606270551526)]
# [(4501, 0.4590744588913307)]
# Plants vs Zombies Sprinter Zombie Plush 11 inch291   Figures & Playsets
#
#
# [(266, 0.9521967563902505)]
# [(386, 0.35147555084362747)]
# Ty Beanie Boo Buddy 9" Plush Maddie the Brown Dog292   Buffer
#
#
# [(4548, 0.7235523560613589)]
# [(4508, 0.3219576044102538)]
# NEW - 5 X Cuddly Brown Teddy Bear - Height 20cm / 8"293   Buffer
#
#
# [(271, 0.5201584334377112)]
# [(313, 0.5091040555541129)]
# Minions - Despicable Me 2 Unicorn Agnes - Cuddly Plush Toy 60 cm294   Buffer
#
#
# [(351, 0.6098540029019719)]
# [(351, 0.41825373102732044)]
# TY Orient the Cat Beanie Baby295   Buffer
#
#
# [(4706, 0.9606776489480069)]
# [(4536, 0.4799263299437954)]
# Koala Bear Soft Toy 20cm (RB440)296   Puppets & Puppet Theatres
#
#
# [(258, 0.4176307886929356)]
# [(258, 0.4668804008628226)]
# Plush Soft Toy White Lamb by Hansa. 18cm. 4562297   Buffer
#
#
# [(4548, 0.15591065730970927)]
# [(4518, 0.4923807609185694)]
# Be My Bear Teddy Bear Passport298   Buffer
#
#
# [(9450, 0.3206602849248491)]
# [(8852, 0.3400374778709182)]
# Marvel Captain America Distressed Shield Logo299   Characters & Brands
#
#
# [(3985, 0.21773765947795512)]
# [(207, 0.2435459650522181)]
# Savannah The Lioness - TY Beanies 10" - Wild Wild Best300   Buffer
#
#
# [(338, 0.22789966068032624)]
# [(4478, 0.2293094878868175)]
# Steiff Wittie Owl (White)301   Buffer
#
#
# [(260, 0.6301287839352785)]
# [(235, 0.4782866348977026)]
# Steiff 28cm Happy Teddy Bear (Beige)302   Buffer
#
#
# [(373, 0.45492524239201143)]
# [(261, 0.30348061453351394)]
# TY Charmer the Unicorn Beanie Baby303   Buffer
#
#
# [(350, 0.4872301518043128)]
# [(8060, 0.38836516468231946)]
# TY Houston the Puppy Dog Beanie Baby304   Buffer
#
#
# [(235, 0.47844507266572955)]
# [(235, 0.37185652012555104)]
# Steiff 40cm Elmar Teddy Bear (Golden Brown)305   Buffer
#
#
# [(304, 0.4857791970372387)]
# [(8060, 0.38044921371272583)]
# TY Fetch the Labrador Dog Beanie Baby306   Buffer
#
#
# [(286, 0.29411728961351424)]
# [(284, 0.22535594761036568)]
# Zigamazoo Striped Cat Plush Toy (Pink)307   Buffer
#
#
# [(9955, 0.31977580389145116)]
# [(4377, 0.4318672401913607)]
# Keel Toys 30cm Dalmatian308   Buffer
#
#
# [(8042, 0.49324151723594123)]
# [(8732, 0.22274505237870387)]
# Manhattan Toy Lavish Lanky Cats Shadow Plush Toy310   Dolls & Accessories
#
#
# [(4444, 0.24212637801203088)]
# [(340, 0.5982681620212702)]
# Charlie Bears - Thistle311   Buffer
#
#
# [(4441, 0.22008199486353594)]
# [(5862, 0.4544207133099638)]
# Totoro Plush (M) (japan import)312   Die-Cast & Toy Vehicles
#
#
# [(271, 0.33114830815266183)]
# [(294, 0.5091040555541129)]
# Despicable Me Minions Unicorn Plush Backpack313   Buffer
#
#
# [(350, 0.45854696491108876)]
# [(4491, 0.28167950573943856)]
# Dewi Y Ddraig the Green Dragon - 6" TY Beanie Baby314   Buffer
#
#
# [(367, 0.5445393952303731)]
# [(281, 0.46749516147118425)]
# Keel Toys 20 cm Chimp315   Buffer
#
#
# [(238, 0.1552436008592426)]
# [(3009, 0.15882559726903528)]
# Miyoni 12-inch Sloth Plush316   Party Supplies
#
#
# [(273, 0.44594321026178046)]
# [(385, 0.31391030884589316)]
# Pokemon Deoxys 15cm/6" Soft Plush Doll Toy #386317   Buffer
#
#
# [(4481, 0.888197616880958)]
# [(247, 0.4487065848829128)]
# Me to You 7-inch Tatty Teddy Bear Flowers and for My Beautiful Wife Plaque (Grey)318   Buffer
#
#
# [(4536, 0.5205941574383073)]
# [(213, 0.6758576760610568)]
# Plush Soft Toy Elephant by Ravensden from The Suma Collection. 19cm. FRS016E320   Buffer
#
#
# [(4368, 0.4471412794440327)]
# [(7247, 0.26117143585239266)]
# Jazwares Poptropica 7 Inch Plush Figure Cool Boy321   Buffer
#
#
# [(4548, 0.3312611422148258)]
# [(4508, 0.2345595255228951)]
# Harrods Xmas Bear 2011 - brand new with tags322   Buffer
#
#
# [(1954, 0.23447801561224701)]
# [(3137, 0.36713262512673284)]
# Pillow Pet 18-inch 1 Direction Puppy (Pink)323   Party Supplies
#
#
# [(275, 0.3503530783421974)]
# [(1430, 0.23439530840732437)]
# GE Entertainment Death Note Plush Toy - 7" Ryuk (GE-7050)324   Buffer
#
#
# [(7919, 0.2548221546462078)]
# [(4571, 0.34991657460922865)]
# Manhattan Toy Finger Puppet Box Set A Day at The Castle325   Puppets & Puppet Theatres
#
#
# [(4470, 0.6601072390788126)]
# [(4518, 0.5038664437651414)]
# Bear Clothes fit 15" Build a Bear Teddies or Similar. Scrubs, Doctor, Nurse Teddy Outfit Personalised With a Name327   Buffer
#
#
# [(354, 0.32725039052510196)]
# [(8078, 0.3373005075631662)]
# Pokemon Plush Toy - Eevee Doll (Size L Large) Around 30cm 12" + Pokemon Sticker328   Buffer
#
#
# [(8723, 0.20079807536544556)]
# [(8060, 0.45229074033255345)]
# TY Cargo the Dog Beanie Baby329   Dolls & Accessories
#
#
# [(330, 0.9999999999999998)]
# [(4491, 0.42778813401360793)]
# Ty Beanie Babies 12" Plush Tiggs the Tiger330   Buffer
#
#
# [(5024, 0.43407253770359366)]
# [(4468, 0.2962063666227169)]
# Bashful Black and Cream Puppy Dog Soft Toy - 31cm - by Jellycat331   Party Supplies
#
#
# [(4430, 0.9933015095879016)]
# [(345, 0.5935145477842146)]
# Webkinz Prairie Dog Plush Toy with Sealed Adoption Code332   Buffer
#
#
# [(8852, 0.13601535693613825)]
# [(3267, 0.4871788013696191)]
# Alice in Wonderland: Alice Plush333   Fancy Dress
#
#
# [(199, 0.7292917871174842)]
# [(199, 0.524477782642056)]
# Smasha-Ballz Mini Van Wolf Plush334   Buffer
#
#
# [(200, 0.18284246556888123)]
# [(6436, 0.5400998706832854)]
# Snoopy - Woodstock Small Soft Toy In Gift Bag335   Figures & Playsets
#
#
# [(4385, 0.14547682741327125)]
# [(218, 0.3723349168825189)]
# Squishable Fox (15")336   Buffer
#
#
# [(6671, 0.19446065417131975)]
# [(9575, 0.36811427878229636)]
# My Little Pony Friendship Magic Collection - Plush Doll 6 Pieces Doll Set 6.5" (Rarity, Pinkie Pie, Applejack, Fluttershy, Rainbow Dash and Twilight Sparkle)337   Hobbies
#
#
# [(4446, 0.5306181257399607)]
# [(302, 0.33437190729969946)]
# Steiff 25cm Classic Teddy Bear (Blond)338   Buffer
#
#
# [(350, 0.3676028226282585)]
# [(274, 0.2748396254019307)]
# TY PJ Bear Pink Small 7" Tall339   Buffer
#
#
# [(4399, 0.7839983773173544)]
# [(202, 0.730603229303472)]
# Charlie Bears Tippeetoes from the 2015 Charlie Bears Plush Collection340   Buffer
#
#
# [(4567, 0.6970165507397204)]
# [(4567, 0.31919472962215045)]
# Sesame Street - Snuffleupagus 17"341   Puppets & Puppet Theatres
#
#
# [(332, 0.9924419176956791)]
# [(332, 0.5935145477842146)]
# Webkinz Jack Russell Dog Plush Toy with Sealed Adoption Code345   Buffer
#
#
# [(3030, 0.21657394766677582)]
# [(1954, 0.17980974285745785)]
# Jet Creations AN-KAN4 48in.L Inflatable Kangaroo346   Party Supplies
#
#
# [(9329, 0.2640762931613841)]
# [(2804, 0.39213975484985697)]
# Pluto Sleepy Pluto Plush Toy347   Characters & Brands
#
#
# [(348, 0.9999999999999999)]
# [(389, 0.3915631316573861)]
# Teddy Bear with doberman, pet, dog image t-shirt348   Buffer
#
#
# [(8377, 0.3033349804967601)]
# [(9217, 0.2544822351623307)]
# Dear Zoo - 5 x Finger Puppets: Dog, Elephant, Giraffe, Monkey and Lion Soft Crate Storage Bag - Rod Campbell349   Characters & Brands
#
#
# [(4429, 0.6340411545269751)]
# [(274, 0.40095775935090977)]
# TY Count the Bear Beanie Baby350   Buffer
#
#
# [(295, 0.6098540029019719)]
# [(295, 0.41825373102732044)]
# Pounce the Cat - TY Beanie Baby351   Buffer
#
#
# [(4368, 0.16752990009187285)]
# [(7783, 0.23639897902670085)]
# COWBOY BEBOP EDWARD & EIN PLUSH352   Characters & Brands
#
#
# [(5224, 0.4438033443687396)]
# [(4364, 0.2391384892957611)]
# McDonalds Happy Meal Toy DIGIMON Adventure Plush GOMAMON353   Games
#
#
# [(2886, 0.20761126070345312)]
# [(1459, 0.2120730637101123)]
# Pack of 24 Artificial Chestnuts - Autumn Winter Christmas Decorations356   Arts & Crafts
#
#
# [(4481, 0.8781249238179007)]
# [(4530, 0.5063363879406535)]
# Me to You 6-inch Tatty Teddy 30th Birthday Bear (Grey)357   Buffer
#
#
# [(4530, 0.963668390529143)]
# [(4552, 0.6409314549224968)]
# Me to You, Tatty Teddy, Grey Teddy Bear Holding A Flower, Sits 6" Tall358   Buffer
#
#
# [(284, 0.8551290929409957)]
# [(4404, 0.6533426642683648)]
# Official Nintendo Super Mario Plush Series Stuffed Toy - 8" Princess Peach (Japanese Import)360   Buffer
#
#
# [(4390, 0.15073028125901786)]
# [(212, 0.3238046501767249)]
# Aurora 8 inch Milly Lying361   Buffer
# [(4548, 0.38535077012266206)]
# [(7146, 0.32107670630441726)]
# Union Jack Cute Hoodie Teddy Bear362   Buffer
#
#
# [(4413, 0.44542346434648783)]
# [(1360, 0.25144569159266067)]
# Plush owl with I Love my man T-shirt363   Buffer
#
#
# [(224, 0.28624589570506564)]
# [(224, 0.6257181863006163)]
# Latitude Enfant 320622 Simon The Lion364   Buffer
#
#
# [(7069, 0.37527211038213804)]
# [(6573, 0.2542304005237959)]
# Despicable Me 2 Electronic Soft Toy - Fluffy Unicorn365   Figures & Playsets
#
#
# [(5698, 0.3083780784723274)]
# [(8104, 0.4164347722755656)]
# Teddy in a Tin - Sleepy Bear - Gift in a Tin from Apples to Pears366   Dolls & Accessories
#
#
# [(315, 0.5445393952303731)]
# [(308, 0.32125314584197784)]
# Keel Toys 20cm Sitting Panda367   Buffer
#
#
# [(2268, 0.1673400300257085)]
# [(6035, 0.21792377595913978)]
# Animagic My Tender Care Twin Puppies368   Figures & Playsets
#
#
# [(8973, 0.13847766705455694)]
# [(4393, 0.381155566735585)]
# Steiff 035807 Will Cinnamon Teddy Bear Limited Edition of 1500369   Buffer
#
#
# [(4470, 0.6429886895240435)]
# [(4518, 0.5022077926480587)]
# Teddy Bear Clothes Pink Sparkle Stripe Outfit fits Build a Bear Factory Teddies370   Buffer
#
#
# [(4430, 0.9923326134300642)]
# [(4430, 0.5392266350959878)]
# Webkinz Batik Elephant Plush Toy with Sealed Adoption Code371   Buffer
#
#
# [(4517, 0.4092000840855522)]
# [(245, 0.3467419362978375)]
# Hansa Wood Hog Plush Soft Toy 26cm Long372   Buffer
#
#
# [(292, 0.5435225492714577)]
# [(330, 0.3610846674031476)]
# Ty Beanie Babies Hello Kitty - Rose, Turquoise and Purple Set of 3 Plush Toys373   Buffer
#
#
# [(4613, 0.49966540384306524)]
# [(4757, 0.2950696218361506)]
# Snuggle Uppets Friendly Brown Bear374   Puppets & Puppet Theatres
#
#
# [(4461, 0.39657337449619173)]
# [(245, 0.2986524731606106)]
# Frog 33cm Soft Toy Plush by Teddy Hermann375   Buffer
#
#
# [(4413, 0.4167878743330446)]
# [(4445, 0.3274146477806382)]
# Nintendo Pokemon Plush Toy - 12" Zoroark Plush Toy -- Yao Design376   Buffer
#
#
# [(4372, 0.5828720789798099)]
# [(6029, 0.24565173721938105)]
# RSPB Turtle Dove377   Buffer
#
#
# [(9027, 0.36934446880415345)]
# [(9027, 0.23330554907908574)]
# Andy's Toy Chest 30cm Buzz Lightyear378   Characters & Brands
#
#
# [(4452, 1.0)]
# [(4725, 0.39912958370129664)]
# Chef Outfit379   Buffer
#
#
# [(350, 0.4741132652277797)]
# [(261, 0.46250832758718086)]
# TY Beanie Baby - Dinky the Duck380   Buffer
#
#
# [(344, 0.3510874962299352)]
# [(344, 0.32348149246294655)]
# Steiff Mickey Mouse381   Characters & Brands
#
#
# [(388, 0.7489816945939803)]
# [(3964, 0.3146159656769996)]
# NICI Snow Leopard Girl dangling 35cm382   Buffer
#
#
# [(264, 0.6308842248094697)]
# [(363, 0.1910789867764066)]
# Tiger plush toy with I Love Alex T-Shirt (first name/surname/nickname)383   Buffer
#
#
# [(6555, 0.3986064522485221)]
# [(4455, 0.349091625744967)]
# Ty Stripes Buddy Beanie Boos 7136911 Soft Toy Tiger Large 21.5 cm384   Figures & Playsets
#
#
# [(350, 0.23359528162483234)]
# [(4465, 0.4583768928866611)]
# Ty Beanie Buddy 12-Inch Schweetheart the Orangutan386   Buffer
#
#
# [(2817, 1.0)]
# [(2872, 0.33869787822023806)]
# Amscan International Sd-H One Direction Zayn387   Party Supplies
#
#
# [(382, 0.7489816945939803)]
# [(4433, 0.2448708075198275)]
# NICI Angel Bean Bag Keyring388   Buffer
#
#
# [(348, 0.9999999999999999)]
# [(348, 0.3915631316573861)]
# Teddy Bear with Cycling image t-shirt389   Buffer
#
#
# [(4553, 0.14656407260704626)]
# [(4553, 0.4999014339721703)]
# Worry Eater Soft Toy - Pomm391   Buffer
#
#
# [(8279, 0.4469284519497088)]
# [(9122, 0.4038864326989917)]
# How To Train Your Dragon Soft Toy Toothless Night Fury Plush 22cm392   Figures & Playsets
#
#
# [(668, 0.8227475338248508)]
# [(4648, 0.31843913541659163)]
# Melissa & Doug Beagle Plush Toy394   Arts & Crafts
#
#
# [(4485, 0.5121776665118033)]
# [(274, 0.367623484572473)]
# TY Beanie Baby Hello Kitty - Peace Bear (Aqua)395   Buffer
#
#
# [(4413, 0.24760424830041086)]
# [(9102, 0.2666657444962617)]
# The Flash - Funko Mopeez Plush Figure - DC Comics396   Figures & Playsets
#
#
# [(302, 0.3002303085200584)]
# [(302, 0.29633028322942156)]
# Steiff Mizzy Lynx (Beige/ Brown)397   Buffer
#
#
# [(3047, 0.11979885744225682)]
# [(385, 0.27008310055445883)]
# Ayumi Be You Doll / Plush / Soft Toy "LOVE" 38 cm with Glitter Trailer by Nici398   Characters & Brands
#
#
# [(621, 0.38239740381031717)]
# [(719, 0.46236626080151505)]
# Santa Claus / Father Christmas Wooden Advent Calendar602   Buffer
#
#
# [(730, 1.0)]
# [(730, 0.7562367328120021)]
# Playmobil 5494 Christmas Advent Calendar Santas Workshop604   Buffer
#
#
# [(628, 0.9999999999999999)]
# [(628, 0.7506867609251858)]
# Deluxe Mini Advent Calendar - Nostalgic House Tealight Lantern - Red House605   Buffer
#
#
# [(8907, 0.21036766639369647)]
# [(790, 0.22536554275430837)]
# Personalised Wedding Couples Keepsake Christmas Bauble606   Buffer
#
#
# [(6420, 0.44074320622279745)]
# [(737, 0.5159279443266337)]
# Playmobil Advent Calendar Xmas607   Figures & Playsets
#
#
# [(781, 0.7256283231241751)]
# [(2829, 0.3315933435597734)]
# 6 Luxury 12" Father Christmas Make Your Own Christmas Crackers611   Buffer
#
#
# [(635, 0.38002554352670603)]
# [(661, 0.26957277108221256)]
# Handcrafted Christmas Advent Candle And Ceramic Holder ~ Snowman613   Buffer
#
#
# [(739, 0.5278521160293294)]
# [(634, 0.4171871587467322)]
# Lego City 2824: Advent Calendar 2010614   Buffer
#
#
# [(604, 0.3592396502567928)]
# [(607, 0.3456529327119959)]
# Playmobil 5493 Christmas Advent Calendar Dragons Treasure Battle617   Buffer
#
#
# [(661, 0.6931487539253424)]
# [(661, 0.3148825954457407)]
# Traditional 3D Advent Calendar620   Buffer
#
#
# [(716, 0.6104618504508476)]
# [(607, 0.3730202736469068)]
# Playmobil 5496 Advent Calendar Christmas Room with Tree621   Buffer
#
#
# [(618, 0.8947978797142457)]
# [(752, 0.5462704354818243)]
# Kinetic Sand Neon Purple Sand 680g622   Arts & Crafts
#
#
# [(1342, 0.15095358374988452)]
# [(3079, 0.15387276379619463)]
# 3 pack TINSEL PURPLE/SILVER 6PLY X 2.24M 12CM624   Party Supplies
#
#
# [(760, 0.29080193307474417)]
# [(765, 0.4066716564059973)]
# LEGO Friends 41016: Advent Calendar626   Buffer
#
#
# [(628, 0.9999999999999999)]
# [(605, 0.7506867609251858)]
# Deluxe Mini Advent Calendar - Nostalgic House Tealight Lantern - Green House628   Buffer
#
#
# [(6945, 0.2439561981972366)]
# [(765, 0.28338827376736303)]
# Elegant Lego Friends Advent Calendar 3316 With 24 Gifts, Mini Dolls, A Dog And Accessories631   Buffer
#
#
# [(729, 0.30071183874649204)]
# [(729, 0.6089412124885368)]
# Schleich Farm Christmas Advent Calendar632   Buffer
#
#
# [(614, 0.4594032094310704)]
# [(614, 0.4171871587467322)]
# LEGO City 7687 Advent Calendar 2009634   Buffer
#
#
# [(699, 1.0)]
# [(699, 0.6397393627420775)]
# Traditional A4 Card Advent Calendar Deluxe - Nostalgic Victorian Christmas Carousel With Glitter Detail635   Buffer
#
#
# [(8119, 0.1512953589644743)]
# [(607, 0.2789671876494284)]
# PLAYMOBIL 5217 SINTERKLAAS ADVENT KALENDER CALENDAR ZWARTE PIET SINT637   Buffer
#
#
# [(620, 0.4582666144067119)]
# [(340, 0.26807030287786204)]
# Polar Bears Advent Calendar638   Buffer
#
#
# [(621, 0.5715124974507586)]
# [(8610, 0.25647218192997595)]
# Playmobil 3943 - Christmas Tree Decorations641   Buffer
#
#
# [(8889, 0.6364027787663974)]
# [(607, 0.39306759955027903)]
# Playmobil 4163 Advent Calendar Knights' Tournament644   Figures & Playsets
#
#
# [(620, 0.46966331129210015)]
# [(607, 0.42350794051286966)]
# Playmobil 4153: Advent Calendar Knights646   Buffer
#
#
# [(620, 0.5949344251547918)]
# [(681, 0.3972449216816373)]
# Advent Gift Boxes Make Your Own Advent Calendar Kit647   Buffer
#
#
# [(620, 0.4647421273340837)]
# [(8231, 0.20379947464079784)]
# Simba Toys 105957618 Filly Fairy - Ice - Advent Calendar650   Buffer
#
#
# [(737, 0.5979996879284026)]
# [(747, 0.39048408116568356)]
# Playmobil - 4158 Advent Calendar "Unicorn in Fairy World"653   Figures & Playsets
#
#
# [(785, 0.3929587788981326)]
# [(795, 0.4949583720323594)]
# 24 Wooden Birdhouse Style Christmas House Advent Calendar Decorations657   Buffer
#
#
# [(700, 1.0)]
# [(700, 0.4150081665848497)]
# Santa & Deer Advent Calendar with Glitter658   Buffer
#
#
# [(774, 1.0)]
# [(774, 0.5166932442605441)]
# Holiday Express Victorian Christmas Locomotive Train Card Advent Calendar With Envelope660   Buffer
#
#
# [(679, 1.0)]
# [(679, 0.5750890323393787)]
# Advent Calendar - Christmas Shopping - a 3D glitter Christmas advent calendar661   Buffer
#
#
# [(678, 0.44677509724155573)]
# [(678, 0.3739278055670484)]
# Mega Bloks - Advent Calendar - Smurfs - 10716663   Buffer
#
#
# [(4322, 0.24938513203933554)]
# [(3289, 0.19464339729698)]
# WREATH HOOK SUCTION CUP666   Die-Cast & Toy Vehicles
#
#
# [(660, 0.49289954471403674)]
# [(604, 0.37375045187577566)]
# Moonlit Santas Sleigh And Reindeer With Children Christmas Card Advent Calendar With Envelope674   Buffer
#
#
# [(756, 0.8438953337316566)]
# [(756, 0.7207955965830991)]
# Alison Gardiner Traditional Advent Calendar: Christmas Ice Skating675   Buffer
#
#
# [(692, 0.6684583759115859)]
# [(7923, 0.4463778226152071)]
# Polly Pocket Advent Calendar676   Buffer
#
#
# [(2543, 0.30796028666385894)]
# [(675, 0.24845972324629903)]
# Penguins On Ice Advent Calendar Cotton Quilting Panel Fabric677   Buffer
#
#
# [(1478, 0.4566244553970817)]
# [(663, 0.3739278055670484)]
# Mega Bloks Moshi Monsters Advent Calendar678   Arts & Crafts
#
#
# [(679, 1.0)]
# [(661, 0.5750890323393787)]
# Advent Calendar - Swan Lake - a 3D glitter Christmas advent calendar679   Buffer
#
#
# [(2475, 0.49954641365573155)]
# [(661, 0.15405586602980265)]
# Simba - Chi Chi Love - Advent Calendar - includes 3 EXCLUSIVE Mini Chi Chi Love Christmas Dogs - 61994683   Buffer
#
#
# [(2970, 0.21328825602130175)]
# [(3108, 0.2957438895629757)]
# MERRY CHRISTMAS PLAQUE RED DECORATION PACK OF 3684   Party Supplies
# [(620, 0.4553506519256563)]
# [(604, 0.32689126194140555)]
# Advent Calendar - Where's Wally - Lots Of Santas - Glitter Varnish Finish687   Buffer
#
#
# [(790, 0.27809003032064344)]
# [(789, 0.4859419174357227)]
# PERSONALISED EMBROIDERED STRIPEY CHRISTMAS STOCKING WITH NAME excluaive to 1stclassgifts st3690   Buffer
#
#
# [(8017, 0.22178882102699884)]
# [(789, 0.37888647397375563)]
# PERSONALISED GIANT SANTA SACK 3d Applique Embroidered with Name in GOLD or WHITE thread691   Buffer
#
#
# [(676, 0.6684583759115859)]
# [(676, 0.3886691052224479)]
# POLLY POCKET Advent Calendar 2011 Floor display, from 4 years (X2456)692   Buffer
#
#
# [(674, 0.32952622228233597)]
# [(3108, 0.19701526415844603)]
# Christmas Magical Reindeer Food Oats Glitter Festive Santa Craft *Rudlolf Charm*696   Buffer
#
#
# [(668, 0.788233808046622)]
# [(6053, 0.35852554594450686)]
# Melissa & Doug Countdown to Christmas Wooden Advent Calendar697   Arts & Crafts
#
#
# [(699, 1.0)]
# [(635, 0.6397393627420775)]
# Traditional A4 Card Advent Calendar Deluxe - Nostalgic Christmas Sleigh With Glitter Detail699   Buffer
#
#
# [(700, 1.0)]
# [(658, 0.4150081665848497)]
# Santa at the Door Advent Calendar with Glitter700   Buffer
#
#
# [(750, 0.2601683269226255)]
# [(647, 0.2183848632253738)]
# Brueghel Advent Calendar703   Figures & Playsets
#
#
# [(660, 0.5405601431442395)]
# [(794, 0.5261612379246905)]
# Extra Large Nostalgic Christmas Village Scene Deluxe Stand Up Card Advent Calendar 84cm704   Buffer
#
#
# [(2844, 0.4403111126333466)]
# [(4878, 0.31940180836147447)]
# Playmobil 4169 Easter Calendar706   Party Supplies
#
#
# [(783, 0.9999999999999999)]
# [(783, 0.5919029359462336)]
# Schleich Horse Christmas Advent Calendar708   Buffer
#
#
# [(4561, 0.19515559916254072)]
# [(4978, 0.28335121504375105)]
# OVERSIZED DOUBLE BELLS DECORATION710   Musical Toy Instruments
#
#
# [(4397, 0.4123503821475528)]
# [(8332, 0.36614131197584376)]
# Monster High advents calendar713   Bags
#
#
# [(621, 0.6104618504508476)]
# [(607, 0.3730202736469068)]
# Playmobil 5497 Christmas Advent Calendar 1.2.3 Animals in the Forest716   Buffer
#
#
# [(602, 0.2325011199554296)]
# [(602, 0.46236626080151505)]
# Hanging Felt Santa Father Christmas Advent Calendar719   Buffer
#
#
# [(634, 0.2970112861903771)]
# [(667, 0.3388916994484845)]
# Lego City 7553: Advent Calendar720   Buffer
#
#
# [(620, 0.2948983630693762)]
# [(724, 0.2599076342506618)]
# Chelsea F.C. Official Snowman Soft Advent Calendar 1M Long723   Buffer
#
#
# [(641, 0.2620352477841952)]
# [(750, 0.3475059855324348)]
# Snowman Forest Animals Decorating the Christmas Tree Advent Calendar 24 x20 cm724   Figures & Playsets
#
#
# [(708, 0.3010680469205132)]
# [(632, 0.6089412124885368)]
# Schleich Farm Christmas Advent Calendar729   Buffer
#
#
# [(730, 1.0)]
# [(604, 0.7562367328120021)]
# Playmobil 5494 Christmas Advent Calendar Santas Workshop730   Buffer
#
#
# [(4405, 0.6428787580492621)]
# [(4476, 0.3294338364935615)]
# Mattel BCK27 - Angry Birds Advent Calendar731   Buffer
#
#
# [(761, 1.0000000000000002)]
# [(761, 0.9052706960829415)]
# Giraffe : Wooden Perpetual Calendar : Traditional Handmade Christmas Gift Ideas : Size 10.5 x 7 x 3.5cm : Buy an Unusual & Quirky Xmas Gift Alternative to an Advent Calendar : Unique and Novelty Stocking Filler : Present for all Ages! Track the Date Forever More!734   Buffer
#
#
# [(795, 0.3556735682303412)]
# [(661, 0.45011447065101745)]
# Wooden Train Christmas Advent Calendar With Drawers735   Buffer
#
#
# [(658, 0.9789060466650744)]
# [(753, 0.42950988212957464)]
# Cartoon nativity Advent Calendar738   Buffer
#
#
# [(614, 0.5278521160293294)]
# [(681, 0.3296988859100211)]
# Lego Kingdoms Advent Calendar 7952739   Buffer
#
#
# [(620, 0.4254338807071401)]
# [(739, 0.30157775739371445)]
# Lego Castle Advent Calendar 7979 NEW / SEALED740   Buffer
#
#
# [(9469, 0.2347705688113173)]
# [(781, 0.21923685399744108)]
# Christmas Santa Hats 80cm deluxe red velveteen with fur trim744   Games
#
#
# [(7119, 0.5149783604617345)]
# [(653, 0.39048408116568356)]
# Playmobil 5492 Christmas Advent Calendar Unicorn Fairyland747   Figures & Playsets
#
#
# [(635, 0.25706437853872893)]
# [(738, 0.42950988212957464)]
# Wooden Nativity Advent Calendar753   Buffer
#
#
# [(675, 0.8438953337316566)]
# [(675, 0.7207955965830991)]
# Alison Gardiner Traditional Advent Calendar: Christmas at the Palace756   Buffer
#
#
# [(663, 0.3103127253119881)]
# [(765, 0.4066716564059973)]
# LEGO Friends 41102 Advent Calendar760   Buffer
#
#
# [(761, 1.0000000000000002)]
# [(734, 0.9052706960829415)]
# Panda : Wooden Perpetual Calendar : Traditional Handmade Christmas Gift Ideas : Size 10.5 x 7 x 3.5cm : Buy an Unusual & Quirky Xmas Gift Alternative to an Advent Calendar : Unique and Novelty Stocking Filler : Present for all Ages! Track the Date Forever More!761   Buffer
#
#
# [(760, 0.30441269692954415)]
# [(626, 0.4066716564059973)]
# LEGO Friends 41040 LEGO Friends Advent Calendar765   Buffer
#
#
# [(1500, 0.297775710476889)]
# [(669, 0.3720983057778461)]
# Sugar free Magnetic Advent Calendar With Traditional Christmas Stickers766   Buffer
#
#
# [(641, 0.3733342675614121)]
# [(6771, 0.3129113400708744)]
# Assorted Paper Mache Christmas Decorations - Pack of 6771   Buffer
#
#
# [(628, 0.9999999999999999)]
# [(605, 0.7395024225904174)]
# Deluxe Mini Advent Calendar - Nostalgic House Tealight Lantern - Brown House772   Buffer
#
#
# [(774, 1.0)]
# [(660, 0.5166932442605441)]
# Green Winter Express Locomotive Train Card Advent Calendar With Envelope774   Buffer
#
#
# [(761, 1.0000000000000002)]
# [(761, 0.8840422303877691)]
# Tawny Owl : Wooden Perpetual Calendar : Traditional Handmade Christmas Gift Ideas : Size 10.5 x 7 x 3.5cm : Buy an Unusual & Quirky Xmas Gift Alternative to an Advent Calendar : Unique and Novelty Stocking Filler : Present for all Ages! Track the Date Forever More!777   Buffer
#
#
# [(620, 0.5059309723822069)]
# [(1049, 0.5706463911311964)]
# Fisher Price - Imaginext - Advent Calendar778   Figures & Playsets
#
#
# [(1414, 0.33902557575226966)]
# [(1437, 0.3487834892017986)]
# Kids Create Countdown to Christmas Reward Chart Wall Hanging Kids Decoration779   Arts & Crafts
#
#
# [(763, 0.8730340519290379)]
# [(607, 0.3472938234797184)]
# Playmobil - 4159 Advent Calendar "Pony Ranch"780   Figures & Playsets
#
#
# [(611, 0.7256283231241751)]
# [(6321, 0.31640555542151116)]
# 6 12" Gold Foil Card +Gold Hats Make Your Own Christmas Crackers781   Buffer
#
#
# [(783, 0.9999999999999999)]
# [(708, 0.5919029359462336)]
# Schleich Horse Christmas Advent Calendar783   Buffer
#
#
# [(3207, 0.27923585824172603)]
# [(753, 0.37643030098456176)]
# Nativity Set784   Buffer
#
#
# [(620, 0.4011862170169241)]
# [(669, 0.5641951142439572)]
# Large Traditional Card Advent Calendar Deluxe - Horse Stables785   Buffer
#
#
# [(690, 0.27809003032064344)]
# [(789, 0.41680691716221696)]
# Personalised Extra Large Christmas Stocking Green790   Buffer
#
#
# [(661, 0.8392927925764152)]
# [(661, 0.5087622347242392)]
# Advent Calendar - Quentin Blake - a glitter Christmas advent calendar791   Buffer
#
#
# [(635, 0.34189302805929267)]
# [(756, 0.6419871036549035)]
# Alison Gardiner Traditional Advent Calendar: Country House Christmas792   Buffer
#
#
# [(735, 0.3556735682303412)]
# [(657, 0.4949583720323594)]
# Nordic Style Wooden House Christmas Advent Calendar With Drawers795   Buffer
#
#
# [(1095, 0.17945116848755904)]
# [(1022, 0.3583218833345633)]
# Fisher-Price Imaginext DC Super Friends Gotham City Collection Exclusive Vehicle - The Joker Suit with Joker1071   Figures & Playsets
#
#
# [(1960, 0.2686883762211874)]
# [(9776, 0.169580793230491)]
# Trendy Bead Tattoos (Packaging May Vary)1307   Fancy Dress
#
#
# [(1768, 0.3569418797729063)]
# [(1665, 0.22522360355494242)]
# Bestway Steel Pro Frame Set Above Ground Pool1655   Sports Toys & Outdoor
#
#
# [(1899, 0.5666378173511732)]
# [(1537, 0.1904511570922506)]
# Evtech(tm) 4 Style Mix Blossom Floral Flowers Animal Butterfly Red Peony Purple Rose Lotus Chinese Rose Colorful 3D Temporary Tattoos Waterproof NightClub Transfer Tattoos1966   Fancy Dress
#
#
# [(6907, 0.7136621448363493)]
# [(3176, 0.21987716543664998)]
# Military Truck & Anti-Aircraft Rockets army war battle solder tank plane #225052396   Buffer
#
#
# [(2141, 0.20527917100473145)]
# [(2536, 0.22352451618239133)]
# LEGO Racers 8384: Jungle Crasher2397   Buffer
#
#
# [(2522, 0.2734290445806887)]
# [(2523, 0.2491770315887022)]
# LEGO Creator "BBC Children in Need" Pudsey bear #300292400   Buffer
#
#
# [(7933, 0.28168653157560813)]
# [(9522, 0.17772129535228734)]
# Playmobil 5602 Pop Stars Stage2401   Dolls & Accessories
#
#
# [(8129, 0.3215484446780028)]
# [(2593, 0.3631225700865919)]
# Mega Bloks 97202 Halo Series Banshee, Blue2403   Buffer
#
#
# [(9149, 0.2948473864974622)]
# [(2593, 0.3800907907385795)]
# Mega Bloks Halo Spartan IV Battle Pack2404   Buffer
#
#
# [(7528, 0.13045555070084583)]
# [(2520, 0.40355919744698615)]
# LEGO Architecture Louvre Building Set2405   Buffer
#
#
# [(7098, 0.34194187131410997)]
# [(6496, 0.29535475354093643)]
# Figure-rise 6 - Accel World Black Lotus Plastic Model Construction Kit2406   Hobbies
#
#
# [(2419, 0.4055091751032169)]
# [(2471, 0.4603698914348821)]
# LEGO Indiana Jones: Colonel Dovchenko Keychain2408   Buffer
#
#
# [(1167, 0.38418525632574796)]
# [(2509, 0.26306282641842715)]
# LEGO Legends of Chima 70105: Nest Dive2409   Figures & Playsets
#
#
# [(2484, 0.27123409398668225)]
# [(2593, 0.36991700808535055)]
# Mega Bloks Halo 97964 - Covenant Scarab2412   Buffer
#
#
# [(788, 0.13777602854817858)]
# [(2520, 0.37975491725168253)]
# LEGO Architecture 21020: Trevi Fountain2413   Buffer
#
#
# [(3980, 0.3871824148660056)]
# [(4085, 0.3500353085130837)]
# Playmobil 5107 Country Speckled Horse with Stall2416   Figures & Playsets
#
#
# [(943, 0.30465514307287367)]
# [(805, 0.4218480229199023)]
# Massey Ferguson 5430 Tractor and Trailer Construction Kit2417   Die-Cast & Toy Vehicles
#
#
# [(2507, 0.24912711844500338)]
# [(2509, 0.25290141442927516)]
# LEGO Chima 70230: Ice Bear Tribe Pack2418   Buffer
#
#
# [(2408, 0.4055091751032169)]
# [(2471, 0.39497792141251964)]
# LEGO Indiana Jones 7682 Template of Doom: Shanghai Chase2419   Buffer
#
#
# [(8399, 0.14879899944175995)]
# [(2523, 0.2828764968554324)]
# LEGO Creator Designer Set 4884: Wild Hunters2420   Buffer
#
#
# [(2490, 0.44199645684892497)]
# [(8217, 0.32235955259181026)]
# Lego Super heroes Flash keyring - 8534542423   Buffer
#
#
# [(2543, 0.2782043800096545)]
# [(7913, 0.3511820404551125)]
# Playmobil 5142 Princess Fantasy Castle2424   Dolls & Accessories
#
#
# [(2522, 0.2584328499295433)]
# [(5862, 0.30361850117944594)]
# Swamp jet 30252 Lego Cima Cragg (japan import)2427   Die-Cast & Toy Vehicles
#
#
# [(2415, 0.4730287493861015)]
# [(6900, 0.30284262072258555)]
# LEGO® Star WarsTM Minifig Watto (from set 7962)2428   Characters & Brands
#
#
# [(8932, 0.39512119727826883)]
# [(8938, 0.24487639307040765)]
# Pirate Ship King Of The Sea 6 pirates minifigures 487 pieces (311)2430   Figures & Playsets
#
#
# [(6930, 0.27077292806519887)]
# [(6930, 0.7044275250911627)]
# mic.o.mic Jet Plane2431   Buffer
#
#
# [(5445, 0.13085800907553358)]
# [(2523, 0.42103687876780893)]
# LEGO Creator 4837: Mini Trains2432   Buffer
#
#
# [(2447, 0.2409718525767889)]
# [(2592, 0.214446306087605)]
# Playmobil 5362 City Action Fire Brigade Engine Ladder Unit with Lights and Sounds2434   Figures & Playsets
#
#
# [(2464, 0.21699471611579352)]
# [(2488, 0.3682598155494457)]
# Meccano Gears of War C.O.G King Raven2435   Buffer
#
#
# [(7234, 0.6180995207516433)]
# [(7234, 0.4832238137333455)]
# LEGO City: Lawn Mower Set 30224 (Bagged)2436   Sports Toys & Outdoor
#
#
# [(4108, 0.16927709851110945)]
# [(4478, 0.21268798163167202)]
# Playmobil - 4478 Deep sea Diving Bell2438   Buffer
#
#
# [(7742, 0.335733060041043)]
# [(2585, 0.377358553256182)]
# Mega Bloks Buildable Blue Mountain Quarry Tub2439   Buffer
#
#
# [(4583, 0.2784520676688133)]
# [(2591, 0.43825243181835716)]
# Playmobil 6644 City Life Zoo Alligator with Babies2440   Buffer
#
#
# [(8939, 0.3309337991773424)]
# [(112, 0.22652212433540592)]
# Playmobil 5539 City Action Coast Guard Station with Lighthouse2444   Figures & Playsets
#
#
# [(5079, 0.5868991034126209)]
# [(5079, 0.4620709605207347)]
# Lego Spongebob Squarepants Mini Figure Spongebob (Shocked Look)2446   Party Supplies
#
#
# [(6917, 1.0)]
# [(8088, 0.2198627231967431)]
# Playmobil 4282 Living Room2448   Buffer
#
#
# [(6924, 0.19719128675841402)]
# [(0, 0.0)]
# ZOOB 5002449   Buffer
#
#
# [(1082, 0.18032550661507613)]
# [(291, 0.24263988332725506)]
# Character Building Monsters VS Zombies Crypt of Terror Playset2450   Buffer
#
#
# [(6896, 0.3336867335560681)]
# [(765, 0.29944729927502395)]
# Lego 40080 Friends Pencil Holder2451   Buffer
#
#
# [(2396, 0.28155503505577917)]
# [(9180, 0.21753487252482973)]
# Supermarket Store Shop Building Bricks Set (289 Pieces)2452   Buffer
#
#
# [(6905, 0.22799305222561023)]
# [(2521, 0.23756968823442287)]
# LEGO Technic 42052: Heavy Lift Helicopter Mixed2453   Buffer
#
#
# [(2527, 0.2682799325639581)]
# [(7826, 0.21592958567482703)]
# Kidoloop Happy Train Track Complete Set 48 pcs With Different Sounds Build & Play2454   Buffer
#
#
# [(6820, 0.21363123874868975)]
# [(1233, 0.2670018897969916)]
# Rainbow blocks2456   Arts & Crafts
#
#
# [(8222, 0.32205897288042995)]
# [(2521, 0.2517332275620182)]
# LEGO Technic 9395: Pick-Up Tow Truck2457   Figures & Playsets
#
#
# [(6923, 0.30510761884105037)]
# [(6941, 0.26011740434068886)]
# Lego Buildable Brick Box (size 2x2) - 401182459   Buffer
#
#
# [(6938, 0.2896536992937037)]
# [(2521, 0.2741898209548991)]
# LEGO Technic 8047: Compact Excavator2460   Buffer
#
#
# [(2473, 0.3039227490974152)]
# [(2521, 0.279941200544668)]
# LEGO Technic 8292: Cherry Picker2461   Buffer
#
#
# [(1629, 0.3386926773493002)]
# [(6925, 0.2208060329958551)]
# LEGO REBEL BLOCKADE RUNNER 100192462   Sports Toys & Outdoor
#
#
# [(2878, 0.3221231174893423)]
# [(2585, 0.28304997789818054)]
# Mega Bloks 2413 Blok Squad - Police Force Chopper 71pc Buildable Playset2464   Buffer
#
#
# [(4049, 0.34290708113053947)]
# [(7779, 0.2618784416892277)]
# Mega Bloks Skylanders Troll Tank Gun Down2466   Figures & Playsets
#
#
# [(8889, 0.7114879540695113)]
# [(641, 0.21227039194099356)]
# Playmobil 4892 Christmas Room2467   Figures & Playsets
#
#
# [(6878, 0.23208793240242923)]
# [(2580, 0.2902946592314637)]
# LEGO Bricks & More 4635: Fun with Vehicles2469   Buffer
#
#
# [(8130, 0.2571148582906423)]
# [(2490, 0.3576634046389831)]
# LEGO Super Heroes 76009: Superman Black Zero Escape2470   Buffer
#
#
# [(6881, 0.19346730102562465)]
# [(9271, 0.23886509864696262)]
# 40 Piece Tegu Explorer Magnetic Wooden Block Set, Jungle2472   Games
#
#
# [(2522, 0.36788643362763557)]
# [(2522, 0.29615134194747816)]
# LEGO City: Cherry Picker Repair Lift Set 30229 (Bagged)2473   Buffer
#
#
# [(2509, 0.5748304186599784)]
# [(2509, 0.29790590968269715)]
# LEGO Chima 70156: Fire vs. Ice2475   Buffer
#
#
# [(1900, 0.26574595582167704)]
# [(5439, 0.21631660415008838)]
# mobilo standard set2477   Fancy Dress
#
#
# [(2417, 0.24289212438626248)]
# [(7390, 0.18709015003726143)]
# Creative Toys Construction Big Nuts and Bolts2478   Buffer
#
#
# [(2494, 0.8524549759987148)]
# [(3657, 0.3793747000979558)]
# Metal Earth Drum Kit2479   Hobbies
#
#
# [(9225, 0.5214942650666753)]
# [(9550, 0.5906968589522381)]
# Mega Bloks Hello Kitty Treehouse2480   Hobbies
#
#
# [(7874, 0.30386478412154083)]
# [(2479, 0.35660030806236925)]
# nanoblock Drum Kit NBC_123 3D puzzle Drum Set2481   Buffer
#
#
# [(2521, 0.286280836228806)]
# [(2521, 0.29055543890134616)]
# LEGO Technic 42022: Hot Rod2482   Buffer
#
#
# [(3994, 0.21027474543500876)]
# [(2588, 0.41314453911977334)]
# LEGO City Police 60128: Police Pursuit Mixed2483   Buffer
#
#
# [(6428, 0.32985031920749475)]
# [(9113, 0.46486909559196293)]
# Mega Bloks Halo UNSC Victor Squad2484   Buffer
#
#
# [(6921, 0.42471700865755446)]
# [(6925, 0.5144365802804672)]
# Laser Pegs 8-in-1 Helicopter Construction Set2485   Buffer
#
#
# [(2492, 0.14476621001506246)]
# [(2576, 0.29156343603482593)]
# Lego Bionicle Pohatu Nuva 85682486   Buffer
#
#
# [(2423, 0.44199645684892497)]
# [(2470, 0.3576634046389831)]
# LEGO Super Heroes 76044: Batman v Superman Clash of the Heroes2490   Buffer
#
#
# [(2486, 0.14476621001506246)]
# [(2576, 0.29465562031599263)]
# LEGO Bionicle 8570 Gali Nuva2492   Buffer
#
#
# [(6135, 0.4014616626275612)]
# [(2591, 0.2340137648317181)]
# Playmobil 4931 Zoo Keeper with Baby Animals2495   Figures & Playsets
#
#
# [(2878, 0.2053684038951208)]
# [(2483, 0.2472665927081073)]
# Lego Space Police 5984 'Lunar Limo'2496   Buffer
#
#
# [(4014, 0.2993022482489266)]
# [(6861, 0.20044631797457454)]
# Ceramic Model - Kukulcan Pyramid, Mexico2498   Figures & Playsets
#
#
# [(6941, 0.8478400591137683)]
# [(2469, 0.2488346949466289)]
# LEGO Bricks: Grey 2x4. Part 3001 (X 25)2501   Buffer
#
#
# [(6547, 0.16957733487191065)]
# [(8821, 0.17695939095473145)]
# Bandai Hobby MSN-06S Master Grade 1/100 Ka Gundam Unicorn Action Figure (Sinanju Stein Version)2502   Figures & Playsets
#
#
# [(4178, 0.35009141081259454)]
# [(3380, 0.2543825217754318)]
# Sluban Ambulance and Jeep2503   Die-Cast & Toy Vehicles
#
#
# [(4276, 0.11885589604057747)]
# [(9379, 0.17738141765877322)]
# Makedo FM01003 Find and Make Dollhouse2504   Arts & Crafts
#
#
# [(6924, 0.30097384494478857)]
# [(5295, 0.20532608696157867)]
# Base Ace 3D Play Platform for Mini Figures, Kit 3 Special Edition2506   Buffer
#
#
# [(1167, 0.2744274783769867)]
# [(6902, 0.3096606269154273)]
# LEGO Ninjago 2115: Bonezai2507   Hobbies
#
#
# [(2190, 0.5538434693792401)]
# [(2190, 0.40389607670732547)]
# Tagamoto City Road Set2508   Hobbies
# [(2475, 0.5748304186599784)]
# [(2475, 0.29790590968269715)]
# LEGO Chima 70151: Frozen Spikes2509   Buffer
#
#
# [(7006, 0.14380964579514288)]
# [(2507, 0.26699151072780897)]
# LEGO Ninjago 70605: Misfortune's Keep Mixed2510   Buffer
#
#
# [(6592, 0.26752769879347904)]
# [(8827, 0.23775493352022659)]
# PLUS PLUS 600 pieces Pastel set2511   Arts & Crafts
#
#
# [(2448, 0.8694245031335187)]
# [(4041, 0.33595268145111135)]
# Playmobil 4912 Dragon Knights Duel2512   Buffer
#
#
# [(2566, 0.3733853215645423)]
# [(2521, 0.27570044536336824)]
# LEGO Technic 42027: Desert Racer2513   Buffer
#
#
# [(2547, 0.627089195177436)]
# [(6929, 0.5583730793359798)]
# Lite Brix Sea Patrol2515   Buffer
#
#
# [(9563, 0.26729716969378187)]
# [(8217, 0.26598405049168344)]
# LEGO Super Heroes 6858: Catwoman Catcycle City Chase2516   Hobbies
#
#
# [(3186, 0.29266914652642556)]
# [(5690, 0.36047570805106544)]
# Warrior Pack (Assortment)2517   Hobbies
#
#
# [(9719, 0.16432905953928983)]
# [(6986, 0.23307062830543407)]
# LEGO Nexo Knights 70334: Ultimate Beast Master Mixed2518   Figures & Playsets
#
#
# [(9719, 0.15862409341059563)]
# [(2405, 0.40355919744698615)]
# Lego Architecture Studio2520   Buffer
#
#
# [(2482, 0.286280836228806)]
# [(6938, 0.30691387679243765)]
# LEGO Technic 8048: Buggy2521   Buffer
#
#
# [(2436, 0.40854024310455506)]
# [(2436, 0.3343478109703292)]
# LEGO City: Tractor Set 4899 (Bagged)2522   Buffer
#
#
# [(7584, 0.32991935000273725)]
# [(2432, 0.42103687876780893)]
# LEGO Creator Mini Cooper Car2523   Buffer
#
#
# [(2540, 0.31500037391256)]
# [(5048, 0.37245897718521215)]
# Nanoblock Electric Guitar Red2524   Musical Toy Instruments
#
#
# [(2399, 0.2311969775194094)]
# [(2399, 0.3558310529190639)]
# LEGO GALAXY SQUAD SPACE SWARMER 707002525   Hobbies
#
#
# [(4044, 0.1803695040942712)]
# [(9377, 0.14534776398778884)]
# LEGO Elves 41173: Elvendale School of Dragons2526   Figures & Playsets
#
#
# [(2454, 0.2682799325639581)]
# [(7241, 0.2698953008124449)]
# Childs Construction Toy Set 130 Piece Mini Harvester - Compatible with the Leading Brick Building Brand2527   Sports Toys & Outdoor
#
#
# [(9180, 0.21190593755602943)]
# [(4013, 0.2938555449420287)]
# Cobi Knights Pavilion2528   Figures & Playsets
#
#
# [(9271, 0.6842277736009547)]
# [(1373, 0.260583289294433)]
# Hape Playscapes Crane Lift Playset2532   Games
#
#
# [(6054, 0.23336326622230508)]
# [(6161, 0.24567546828839776)]
# LEGO Dino 5883: Pteranodon Tower Takedown2534   Figures & Playsets
#
#
# [(2566, 0.28315626902726504)]
# [(2521, 0.2732778957367845)]
# LEGO Technic 42033: Record Breaker2535   Buffer
#
#
# [(765, 0.2788590881004892)]
# [(765, 0.2717108608926838)]
# LEGO Friends 41036: Jungle Bridge Rescue2536   Buffer
#
#
# [(1490, 0.1413293233645762)]
# [(1973, 0.2225795109117134)]
# LEGO Thanksgiving 40123 - year 2015 version (NEW)2537   Fancy Dress
#
#
# [(8256, 0.907773927054305)]
# [(1153, 0.30025719875313206)]
# Lego DC Comics Super Heroes 30303 The Joker Bumper Car Promo Polybag2538   Figures & Playsets
#
#
# [(7063, 0.29975121186678544)]
# [(7063, 0.46741063456666254)]
# Character Building Scooby Doo Mystery Machine Set2539   Figures & Playsets
#
#
# [(7865, 0.9753928264870156)]
# [(2524, 0.26836847436600325)]
# Nanoblock Mallard Duck2540   Die-Cast & Toy Vehicles
#
#
# [(8130, 0.38159422483581873)]
# [(6924, 0.12326016970410968)]
# LEGO Games 3859: Heroica Caverns of Nathuz2541   Figures & Playsets
#
#
# [(2554, 0.414216155766166)]
# [(2554, 0.33405066721065496)]
# ...
#
#
# [(292, 0.6120624288455865)]
# [(261, 0.30945293772819776)]
# Ty Beanie Ballz - Flash the Hamster4484   Buffer
#
#
# [(9225, 0.5740777111786479)]
# [(9225, 0.3290840385876034)]
# Hello Kitty Baby - Fashionista, 15cm [German Version]4485   Characters & Brands
#
#
# [(375, 0.3907218332167069)]
# [(4461, 0.33024142982412374)]
# Hermann Teddy Jointed 40cm Growler4486   Buffer
#
#
# [(370, 0.5953229206024596)]
# [(370, 0.47786430681497727)]
# Bear clothes fits build a bear teddies red fleece robe 15 inch bear clothing4487   Buffer
#
#
# [(232, 0.5618778013591683)]
# [(298, 0.3213694687571076)]
# Me to You Bear Wedding Planner4488   Buffer
#
#
# [(4482, 0.4344693054940917)]
# [(4522, 0.5081634818972492)]
# Pillow Pets Unicorn4490   Buffer
#
#
# [(4497, 0.8457752085147381)]
# [(4417, 0.4500236512519351)]
# TY Beanie Babies Plush - Legend the Red Dragon 15cm4491   Buffer
#
#
# [(1600, 0.19980713837972375)]
# [(315, 0.42898318749596437)]
# Keel Toys 17 cm Bulldog in Coat4494   Buffer
#
#
# [(4482, 0.24586922747410195)]
# [(234, 0.2239921897597339)]
# Fiesta Toys 18" Plush PENGUIN Peek-A-Boo Pillow4495   Buffer
#
#
# [(4400, 0.4707359303093409)]
# [(4438, 0.32740729991693696)]
# Pokemon 8-inch Plush Pikachu4496   Buffer
#
#
# [(4491, 0.8457752085147381)]
# [(4455, 0.4531498474373248)]
# Ty Beanie Boos - Jinxy the Cat Halloween4497   Buffer
#
#
# [(7986, 0.2778684072926607)]
# [(4468, 0.20622337608209546)]
# Perfect Petzzz Sleeping and Breathing Cavalier King Charles Puppy New soft Version4498   Dolls & Accessories
#
#
# [(4455, 0.23527691225370137)]
# [(295, 0.37641779286373356)]
# Ty Beanie Babies Sneaky the Black Cat Halloween4499   Buffer
#
#
# [(4717, 0.23344554766609515)]
# [(4455, 0.42179643159888197)]
# Ty Beanie Boos - Opal the Owl (Exclusive)4503   Buffer
#
#
# [(8161, 0.38340170788450917)]
# [(4433, 0.21843103398191813)]
# NICI Shirley Sheep Standing 50 cm4505   Figures & Playsets
#
#
# [(238, 0.2276373860109219)]
# [(8010, 0.581003527285738)]
# TY Beanie Boo Key Clip Tundra The Polar Bear4506   Dolls & Accessories
#
#
# [(3718, 0.3260292169803488)]
# [(343, 0.23021743091797842)]
# Giant Brown Tiger Soft Toy 150cm4507   Hobbies
#
#
# [(4548, 0.8903473766121456)]
# [(4439, 0.44102561041730703)]
# NEW ISLA Teddy Bear - Cute And Cuddly - Gift Present Birthday Xmas Isla4508   Buffer
#
#
# [(205, 0.9703640090957549)]
# [(205, 0.5828614969966651)]
# Aurora 5 inch Yoohoo and Friends Tiger (Yellow)4509   Buffer
#
#
# [(4480, 0.5776488842926568)]
# [(4421, 0.29035164543189085)]
# TY UK 6-inch Diego Ice Age Beanie4510   Buffer
#
#
# [(4558, 0.30044241874486965)]
# [(7375, 0.2756197784272752)]
# My Blue Nose Friends 4" Digger the Terrier - Retired4511   Buffer
#
#
# [(234, 0.3958731918248108)]
# [(1015, 0.2748495583691202)]
# Great Eastern S.A.O. Sword Art Online Kirito 9" Plush Doll4512   Buffer
#
#
# [(2422, 0.31796302602398957)]
# [(4910, 0.3039670771111924)]
# Tobar Penguin Duet Soft Toy4513   Party Supplies
#
#
# [(3268, 0.2235995857185649)]
# [(7985, 0.5851359205411305)]
# Fisher-Price Mr Men Little Miss Chatterbox4515   Dolls & Accessories
#
#
# [(372, 0.4092000840855522)]
# [(245, 0.5643336580922979)]
# Plush Soft Toy Seal by Teddy Hermann. 26cm. 90127.4517   Buffer
#
#
# [(4548, 0.35510910343750574)]
# [(4452, 0.5497823283378818)]
# Constuction Worker / Builder Outfit / Teddy Bear Clothes to fit Build a Bear / Bear Factory4518   Buffer
#
#
# [(8402, 0.25781497679671805)]
# [(4367, 0.46266183648045617)]
# Keel Toys soft plush toy fox4519   Buffer
#
#
# [(4522, 0.9999999999999999)]
# [(4490, 0.5081634818972492)]
# Pillow Pets Hello Kitty4522   Buffer
#
#
# [(4386, 1.0000000000000002)]
# [(4404, 0.6404461148242515)]
# Official Nintendo Super Mario Plush Series Stuffed Toy - 8" Lemmy Koopa / Remi4524   Buffer
#
#
# [(4391, 0.30953776925810683)]
# [(3776, 0.16994904161825175)]
# Ty Angeline - Happy Valentine's Day Doll with Gift Box4525   Buffer
#
#
# [(4413, 0.2366210464236443)]
# [(6542, 0.15358590765520064)]
# Set Of 2 Dreamworks 'The Croods' 11 Inch Soft Toys BELT AND MOUSEPHANT (PL92)4526   Buffer
#
#
# [(1433, 0.21666957075481635)]
# [(4127, 0.20226870382363313)]
# Sticky Jelly Toy (Single Item supplied)4527   Arts & Crafts
#
#
# [(4496, 0.2844634289521457)]
# [(228, 0.4616352999794434)]
# Pokemon Center Plush Doll Mega Lucario4528   Buffer
#
#
# [(232, 0.6204071201993557)]
# [(3042, 0.3442214464621727)]
# Me to You I Love My Mum - 408704529   Buffer
# [(358, 0.963668390529143)]
# [(357, 0.5063363879406535)]
# Me to You 12-Inch Tatty Teddy (Grey)4530   Buffer
#
#
# [(7479, 0.16612999440741194)]
# [(4402, 0.304610636793895)]
# HOOTY FRIENDS Pig Heatable Soft Toy4531   Buffer
#
#
# [(269, 0.33085538172695633)]
# [(7460, 0.37162531485155165)]
# Doctor Who Tardis Stress Toy4532   Jigsaws & Puzzles
#
#
# [(4538, 0.17837981660186716)]
# [(261, 0.33863234623700733)]
# TY Garfield 4-H Beanie Baby4533   Buffer
#
#
# [(3319, 0.08977013427594417)]
# [(8868, 0.2131943111397425)]
# Musical Leprechaun4534   Figures & Playsets
#
#
# [(4479, 0.5894766337430428)]
# [(4479, 0.3388367349709591)]
# Pinky the Guinea Pig - 5" Original Beanie4535   Buffer
#
#
# [(320, 0.5205941574383073)]
# [(320, 0.5133017795494809)]
# Plush Soft Toy Koala Bear from The Suma Collection by Ravensden. 20cm. FRS039A4536   Buffer
#
#
# [(4389, 0.3941895349379442)]
# [(4389, 0.5650102832714802)]
# MY LITTLE PONY - MY LITTLE PONY PLUSH 12 INCHES - APPLE BLOOM 25 cm4538   Buffer
#
#
# [(3955, 0.19374891477441764)]
# [(298, 0.22068745518144472)]
# 1 Kilo Rhomboid Mix Memory Foam Toy, Teddy Bear, Cushion, Pillows, Stuffing, Filling.4540   Buffer
#
#
# [(5603, 0.23462324882248015)]
# [(3858, 0.2590415852589681)]
# Vampire Stuart Minion - PLUSH Big 60cm MINIONS Movie 2015 - Official4541   Characters & Brands
#
#
# [(293, 0.32724996019217145)]
# [(7999, 0.19766806079711044)]
# Matfield Lavender Gifts Wheat Cuddle Bear4542   Buffer
#
#
# [(229, 0.22981659595607346)]
# [(255, 0.3110814551470661)]
# Lil'Kinz Mini Plush Stuffed Animal Pink Poodle4543   Buffer
#
#
# [(229, 0.8459408024300126)]
# [(248, 0.2901795900744417)]
# Webkinz Llama Soft Toy4547   Buffer
#
#
# [(4483, 0.9253163735993837)]
# [(4483, 0.36663133977179513)]
# NEW - Spain / España Flag Teddy Bear - Present Gift - Spanish Football Fan4548   Buffer
#
#
# [(9565, 0.5194323723877812)]
# [(5434, 0.17542160617394412)]
# BAD TASTE BEARS - Statuette Scratch N Sniff 11 cm4549   Hobbies
#
#
# [(1045, 0.33682170451994836)]
# [(4456, 0.383582979912908)]
# Nintendo 13cm Mario Bros Plush San-ei - Baby Mario4551   Buffer
#
#
# [(247, 0.41183441467702314)]
# [(4481, 0.666499876664126)]
# Me to You, Tatty Teddy, Grey Teddy Bear Holding an Eighteen Heart Shaped Cushion, Sits 9" Tall4552   Buffer
#
#
# [(391, 0.14656407260704626)]
# [(391, 0.4999014339721703)]
# Worry Eater Pat Plush Toy4553   Buffer
#
#
# [(1050, 0.29904351576751087)]
# [(1050, 0.29629903449022466)]
# One pair Miku Hatsune Vocaloid rin+len 7" Plush Doll Toy4554   Figures & Playsets
#
#
# [(348, 0.9999999999999999)]
# [(298, 0.3727651725868033)]
# Teddy Bear with I Love Nana t-shirt4555   Buffer
#
#
# [(254, 0.8790216068753214)]
# [(358, 0.5038612576445015)]
# Me to You 3-inch Tatty Teddy Bear Hanging Christmas Tree Decoration Sits (Grey)4556   Buffer
#
#
# [(4413, 0.2733179905040835)]
# [(376, 0.21039702431122684)]
# Worms Super Sheep Plush Toy with Soundchip4557   Buffer
#
#
# [(250, 0.8327301784251514)]
# [(250, 0.47771144765306933)]
# Me To You 4-inch Tatty Teddy and My Blue Nose Friends Abbey The British Cat Soft Toy4558   Buffer
#
#
# [(3884, 0.5884219208986491)]
# [(8391, 0.708709725025945)]
# Lovely Donkey Shape Soft Baby Wrist Rattle Toy Hands Finder---Green4559   Baby & Toddler Toys
#
#
# [(3087, 0.4315317430712023)]
# [(2889, 0.3245603774137492)]
# 2 X Amscan Casino Swirls 12-Decorations5149   Party Supplies
#
#
# [(2651, 0.291079784878913)]
# [(5679, 0.3127823101560312)]
# Munchkin Card Game: The Guild Expansion5156   Hobbies
#
#
# [(5679, 0.23924444308809978)]
# [(5360, 0.28176368239673544)]
# Munchkin 7 Cheat With Both Hands5369   Games
#
#
# [(5266, 0.26809022970961793)]
# [(5242, 0.3408011081026995)]
# Top Trumps - Beano5381   Games
#
#
# [(5389, 0.26428081398758435)]
# [(7815, 0.27599211543737)]
# Tally Ho Poker5433   Hobbies
#
#
# [(9152, 0.22189390894949707)]
# [(6446, 0.5658992288770683)]
# Jurassic World Bashers & Biters Velociraptor Blue Figure6073   Characters & Brands
#
#
# [(1161, 0.2546901648591351)]
# [(1161, 0.5048821915367485)]
# Kotobukiya Samurai Chopsticks: Masamune Date Toy6452   Figures & Playsets
#
#
# [(6736, 0.2693707809061045)]
# [(6592, 0.23151860836760735)]
# Domire 3 Pcs Colorful Pencils For Children Kids Style 36567   Arts & Crafts
#
#
# [(6825, 0.3149850432521079)]
# [(2153, 0.3684938835291637)]
# K'NEX Model 52 Building Set6878   Hobbies
#
#
# [(5857, 0.4295464387862731)]
# [(4981, 0.32221215378373586)]
# Mega Bloks Power Rangers Snake Mechazord 57986879   Die-Cast & Toy Vehicles
#
#
# [(8285, 0.6694590232979046)]
# [(8251, 0.4471557531301701)]
# Lego Minifigures Series 3 - TRIBAL CHIEF6880   Figures & Playsets
#
#
# [(6813, 0.2569767555148138)]
# [(6807, 0.25747812185280927)]
# Wooden Twisty Blocks Toy - Pocket Money Toy - Stocking Filler6881   Baby & Toddler Toys
#
#
# [(4133, 0.17795962311688693)]
# [(2507, 0.26699151072780897)]
# LEGO Ninjago 9440: Venomari Shrine6883   Buffer
#
#
# [(6042, 0.24807205623422507)]
# [(6161, 0.291314990120955)]
# Clics 7-in-1 Dino Squad Drum6891   Figures & Playsets
#
#
# [(4150, 0.3629061973314931)]
# [(841, 0.1484073074656544)]
# Playmobil 5150 E-Rangers Turbojet with Launch Pad6893   Figures & Playsets
#
#
# [(2590, 0.18711015686075402)]
# [(2574, 0.3913514289245315)]
# Meccano Eiffel Tower Construction Set6894   Buffer
#
#
# [(8239, 0.9099438118463405)]
# [(8239, 0.5022305470765812)]
# Penzora Custom Minifigure Spongebob as Despicable Me Minion Printed on LEGO parts6896   Figures & Playsets
#
#
# [(8434, 0.29908671222675653)]
# [(4855, 0.25932194461642527)]
# The Big Ben of London - England6897   Die-Cast & Toy Vehicles
#
#
# [(8285, 0.6160420951636383)]
# [(8225, 0.5191769719474244)]
# LEGO Minifigures Series 9 Roller Derby Girl (opened packet)6898   Figures & Playsets
#
#
# [(1, 0.0)]
# [(2428, 0.30284262072258555)]
# LEGO® Star WarsTM Salacious B. Crumb Minifigure from set 95166900   Buffer
#
#
# [(6546, 0.12844577681475966)]
# [(1359, 0.24176618633994926)]
# LEGO Hero Factory 44001: Pyrox6903   Arts & Crafts
#
#
# [(6950, 0.1749692121448919)]
# [(6950, 0.2865359511566514)]
# LEGO Atlantis 8075: Neptune Carrier6904   Buffer
#
#
# [(8208, 0.28172641020782435)]
# [(2521, 0.2774536616626388)]
# LEGO Technic 8068: Rescue Helicopter6905   Figures & Playsets
#
#
# [(2396, 0.7136621448363493)]
# [(4791, 0.24598943587402416)]
# Ausini Football Brand New Box Set / Sport Soccer Game Playable City Pitch #256906907   Buffer
#
#
# [(8212, 0.3636526956218007)]
# [(2507, 0.26989473838263855)]
# LEGO Ninjago 70747 Boulder Blaster6908   Figures & Playsets
#
#
# [(634, 0.19304058561618925)]
# [(2407, 0.24579614884380444)]
# Lego City Burglars magnet set6911   Characters & Brands
#
#
# [(7738, 0.24403049679379582)]
# [(4226, 0.21226705200603377)]
# LEGO City Airport 60022: Cargo Terminal6915   Die-Cast & Toy Vehicles
#
#
# [(6917, 1.0)]
# [(9713, 0.19188488351671038)]
# Playmobil 4287 Childrens Room6917   Buffer
#
#
# [(2547, 0.6225182990559451)]
# [(6929, 0.5620412376526274)]
# Lite Brix Space Trooper6918   Buffer
#
#
# [(4108, 0.32967729645869154)]
# [(4059, 0.206796877744153)]
# Playmobil 5210 Figurines Great Dane with Pup6920   Figures & Playsets
#
#
# [(2485, 0.42471700865755446)]
# [(2485, 0.503947485075894)]
# Laser Pegs 6-in-1 Zippy Do Tractor Construction Set6921   Buffer
#
#
# [(7789, 0.3562344388617502)]
# [(4153, 0.16048586229235223)]
# TIPPER TRUCK Roadworks Crew - BLOCK TECH Construction Blocks - 96 pieces6922   Die-Cast & Toy Vehicles
#
#
# [(2459, 0.30510761884105037)]
# [(765, 0.27603116190535004)]
# LEGO Friends - 201Pcs Buildable Jewellery Box6923   Buffer
#
#
# [(2506, 0.30097384494478857)]
# [(765, 0.24554475420305427)]
# LEGO Classic 10692 LEGO Creative Bricks6924   Buffer
#
#
# [(2485, 0.32908434560520217)]
# [(2485, 0.5144365802804672)]
# Laser Pegs 8-in-1 Runner Tank Construction Set6925   Buffer
#
#
# [(3634, 0.2118325051678974)]
# [(3660, 0.22109500140905297)]
# Trumpeter 1:35 - German WR 360 C12 Locomotive6927   Hobbies
#
#
# [(2431, 0.27077292806519887)]
# [(2431, 0.7044275250911627)]
# mic-o-mic Small Locomotive6930   Buffer
#
#
# [(1142, 0.4691507217567626)]
# [(8217, 0.25322065393338833)]
# LEGO Super Heroes: Hawkeye with Equipment Set 30165 (Bagged)6931   Figures & Playsets
#
#
# [(7245, 0.2584457723903265)]
# [(6878, 0.23656332280584982)]
# K'NEX K Force 10 Dart Pack and Target6933   Sports Toys & Outdoor
#
#
# [(760, 0.19507269003909308)]
# [(765, 0.25455742246175983)]
# LEGO Friends 41031: Andrea's Mountain Hut6934   Buffer
#
#
# [(8245, 0.3986302846566677)]
# [(6882, 0.30425968745523013)]
# LEGO Pirates of the Caribbean: Hector Barbossa Pegleg Minifigure6935   Figures & Playsets
#
#
# [(8245, 0.4657380558122511)]
# [(8245, 0.37551856492040425)]
# LEGO Pirates of the Caribbean: Battle Pack: Jack Sparrow, Scrum, Lieutenant Theodore Grove, 2 Zombie Pirates6936   Figures & Playsets
#
#
# [(3518, 0.2938625826303775)]
# [(2521, 0.30691387679243765)]
# LEGO Technic 8294: Excavator6938   Buffer
#
#
# [(5079, 0.5123252083817975)]
# [(2446, 0.4407268476958369)]
# LEGO Spongebob Squarepants: Sandy Spacesuit Keychain6939   Party Supplies
#
#
# [(2501, 0.8478400591137683)]
# [(2459, 0.26011740434068886)]
# LEGO Bricks: Orange 2x2. Part 3003 (X 50)6941   Buffer
#
#
# [(2589, 0.21611226567129352)]
# [(2576, 0.3367508318658524)]
# LEGO Bionicle 8920 Ehlek6942   Buffer
#
#
# [(2448, 0.9959070508949399)]
# [(9377, 0.16247486495963243)]
# Playmobil 4324 Furnished School Building6943   Buffer
#
#
# [(2412, 0.24460210380965383)]
# [(2593, 0.3386371421828249)]
# Halo "Mega Bloks Scorpion's Sting" Building Set (Grey)6944   Buffer
#
#
# [(2662, 0.37122939847921205)]
# [(719, 0.3284197421999419)]
# LEGO Santa Minifigure - LEGO Holiday Father Christmas figure with Present Sack6945   Hobbies
#
#
# [(634, 0.3022931821966399)]
# [(2878, 0.33912001939895825)]
# Lego 60009 City Helicopter Arrest6946   Buffer
#
#
# [(9396, 0.3611197549647674)]
# [(8217, 0.5638110325010022)]
# Doc Ock Truck Heist LEGO® Super Heroes Set 760156947   Figures & Playsets
#
#
# [(2548, 0.24687701427201653)]
# [(2548, 0.5191982035556237)]
# Mega Bloks Call of Duty Motorbike Breakout Collector Construction Set6948   Buffer
#
#
# [(8869, 0.2744950310888275)]
# [(6904, 0.2865359511566514)]
# LEGO Atlantis 7985: City of Atlantis6950   Buffer
#
#
# [(9701, 0.37615493439794323)]
# [(9951, 0.28999188562237666)]
# Viga Wooden 24 Piece Tool Kit6951   Arts & Crafts
#
#
# [(7786, 0.39089379202652674)]
# [(9817, 0.19820075232523526)]
# eitech 00142 Metal Construction Set Switch and Battery Holder6952   Die-Cast & Toy Vehicles
#
#
# [(1761, 0.47839759166527573)]
# [(1761, 0.5044061990372904)]
# Bestway 40 x 10-inch Ocean Life Paddling Pool for Kids7180   Sports Toys & Outdoor
#
#
# [(4253, 0.2907171718300798)]
# [(7291, 0.44026586200332996)]
# Wader My First Truck Crane7185   Buffer
#
#
# [(7238, 0.7217987030104284)]
# [(1514, 0.234916143009094)]
# Twigz Plant Labels (Two Packs Supplied)7206   Gardening
#
#
# [(6778, 0.3530714541281941)]
# [(7185, 0.2975908722379707)]
# Wader Construction Cement Mixer7237   Baby & Toddler Toys
#
#
# [(6012, 0.8536934549336241)]
# [(4532, 0.3222436133895273)]
# Doctor Who Tardis Bigger on the Inside Welcome Mat7284   Figures & Playsets
#
#
# [(7895, 0.4453523733552373)]
# [(7185, 0.44026586200332996)]
# Wader Super Truck Refuse Lorry7291   Die-Cast & Toy Vehicles
#
#
# [(4400, 0.4268644737687244)]
# [(4400, 0.40988175977001734)]
# Pokemon Pillow (Cushion) Pokemon Pikachu Plush Doll New Limited 33CM8078   Buffer
#
#
# [(189, 0.3693965350826887)]
# [(5406, 0.3186782324329998)]
# Playmobil 4945 Pirate on Treasure Hunt Gift Egg8923   Hobbies
#
#
# [(6428, 0.316941726084151)]
# [(2484, 0.46486909559196293)]
# Mega Bloks Halo 97134 - UNSC Night Ops Gausshog9113   Buffer
#
#
# [(2320, 0.2945901491187435)]
# [(7891, 0.24921030143776715)]
# Fajiabao Educational Classic Electronic Racing Car Railway Track Toys & Rail Set Hot Gift Toys for Kids Boys Birthday Gifts (style A)9333   Hobbies
#
#
# [(7346, 0.2690848273841907)]
# [(9197, 0.3543970370989801)]
# Hungry Hungry Hippos Elefun & Friends Board Game9434   Characters & Brands
#
#
# [(9718, 0.31182662680038825)]
# [(9731, 0.5337923313000406)]
# Friendship Charm Bracelet Jewellery Making Kit - Hearts Edition9664   Arts & Crafts
#
#
# [(9975, 0.2038477506199772)]
# [(9975, 0.37810668040839207)]
# Stark Sigil Pendant (costume) Game of Thrones The Noble Collection9961   Hobbies

# %% [markdown]
# # Testing

# %%
mapping['FunkyBuys® Large Christmas Holiday Express Festive Train Set (SI-TY1017) Toy Light / Sounds / Battery Operated & Smoke1']
# Out:
# 1

# %%
match=0
mismatch=0
freq2={}
for i in category_df['product_name'][1:10000]:
    index=mapping[i]
    s=category_df['amazon_category_and_sub_category'].iloc[index]
    ans=category_pred(i)
    
    if s==ans:
        match+=1
    else:
        mismatch+=1
        
    if s in freq2:
        freq2[s]+=1
    else:
        freq2[s]=1
    #print(s,ans)

# %%
print(match,mismatch)
# Out:
# 6993 3006

# %%
plt.figure(figsize=(30,10))
for i in sorted(freq2):
    print(i,freq2[i])
    if(freq2[i]>300):
        plt.bar(i, freq2[i], color='skyblue',width=0.5)
# Out:
# Arts & Crafts 802
# Baby & Toddler Toys 106
# Bags 4
# Bedding & Linens 1
# Buffer 690
# Camping & Hiking 1
# Car Parts 1
# Characters & Brands 960
# Cooking & Dining 4
# Die-Cast & Toy Vehicles 1221
# Dogs 2
# Dolls & Accessories 371
# Educational Toys 3
# Electronic Toys 5
# Fancy Dress 585
# Figures & Playsets 1111
# Games 941
# Gardening 3
# Handbags & Shoulder Bags 1
# Hobbies 1463
# Home Accessories 5
# Indoor Lighting 2
# Jams, Honey & Spreads 1
# Jigsaws & Puzzles 274
# Lab & Scientific Products 1
# Laundry, Storage & Organisation 1
# Medical Supplies & Equipment 1
# Medication & Remedies 2
# Men 1
# Musical Toy Instruments 19
# Novelty & Special Use 11
# Novelty Jewellery 1
# Office Supplies 6
# Party Supplies 694
# Pens, Pencils & Writing Supplies 7
# Pretend Play 45
# Puppets & Puppet Theatres 269
# Sex & Sensuality 1
# Sports Toys & Outdoor 372
# Storage, Cleaning & Ring Sizers 1
# Supporters' Gear 2
# Sweets, Chocolate & Gum 2
# Women 3
# Worlds Apart 3
